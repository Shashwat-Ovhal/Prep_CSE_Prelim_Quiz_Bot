# %%
import pandas as pd

# Data structure containing all 100 Current Affairs MCQs
current_affairs_data = [
    {
        "Question": "The concept of 'One Nation, One Election' necessitates constitutional amendments to which of the following provisions?",
        "Option1": "Article 83 (Duration of Houses of Parliament)",
        "Option2": "Article 172 (Duration of State Legislatures)",
        "Option3": "Article 356 (Provisions in case of failure of constitutional machinery in State)",
        "Option4": "All of the above",
        "Correct Option": "All of the above"
    },
    {
        "Question": "Consider the following statements regarding the Uniform Civil Code (UCC):\n1. It is mentioned in Article 44 of the Directive Principles of State Policy.\n2. The 42nd Constitutional Amendment Act inserted Article 44 in the Constitution.\n3. Goa is the only state in India currently having a UCC.\nWhich of the statements given above is/are correct?",
        "Option1": "1 only",
        "Option2": "1 and 3 only",
        "Option3": "2 and 3 only",
        "Option4": "1, 2, and 3",
        "Correct Option": "1 only"
    },
    {
        "Question": "The 'PMLA' (Prevention of Money Laundering Act), often seen in news, is enforced by which government agency?",
        "Option1": "Central Bureau of Investigation (CBI)",
        "Option2": "National Investigation Agency (NIA)",
        "Option3": "Enforcement Directorate (ED)",
        "Option4": "Directorate of Revenue Intelligence (DRI)",
        "Correct Option": "Enforcement Directorate (ED)"
    },
    {
        "Question": "The 'SWAMIH Fund' (Special Window for Affordable and Mid-Income Housing) is associated with which sector?",
        "Option1": "Agriculture",
        "Option2": "Micro, Small, and Medium Enterprises (MSMEs)",
        "Option3": "Real Estate",
        "Option4": "Startups and Venture Capital",
        "Correct Option": "Real Estate"
    },
    {
        "Question": "Which report or index is published by the NITI Aayog to measure progress towards global development goals at the sub-national level in India?",
        "Option1": "Global Hunger Index (GHI)",
        "Option2": "SDG India Index",
        "Option3": "Ease of Doing Business Index",
        "Option4": "Multi-dimensional Poverty Index (MPI) (India Specific)",
        "Correct Option": "SDG India Index"
    },
    {
        "Question": "The recent amendments to the IT Rules, 2021 (Information Technology Rules) are related to:",
        "Option1": "Regulation of OTT (Over-the-Top) platforms.",
        "Option2": "Establishing a framework for OBC (Online Gaming Companies).",
        "Option3": "Establishing Fact Check Units (FCUs) to counter misinformation.",
        "Option4": "Mandating local data storage for all social media companies.",
        "Correct Option": "Establishing Fact Check Units (FCUs) to counter misinformation."
    },
    {
        "Question": "The term 'Delimitation' in the context of the Indian Parliament is primarily concerned with:",
        "Option1": "The reservation of seats for Scheduled Castes and Scheduled Tribes.",
        "Option2": "The act of fixing limits or boundaries of territorial constituencies.",
        "Option3": "The process of removing a Member of Parliament (MP) on grounds of defection.",
        "Option4": "Determining the number of seats for a State in the Lok Sabha.",
        "Correct Option": "The act of fixing limits or boundaries of territorial constituencies."
    },
    {
        "Question": "Which state recently announced the implementation of the Old Pension Scheme (OPS), a move with significant fiscal implications?",
        "Option1": "Gujarat",
        "Option2": "Madhya Pradesh",
        "Option3": "Uttar Pradesh",
        "Option4": "Himachal Pradesh (and others like Rajasthan, Chhattisgarh)",
        "Correct Option": "Himachal Pradesh (and others like Rajasthan, Chhattisgarh)"
    },
    {
        "Question": "The 'Women's Reservation Bill' (Nari Shakti Vandan Adhiniyam) seeks to reserve what proportion of seats in the Lok Sabha and State Legislative Assemblies for women?",
        "Option1": "10%",
        "Option2": "25%",
        "Option3": "33%",
        "Option4": "50%",
        "Correct Option": "33%"
    },
    {
        "Question": "The 'Pradhan Mantri Jan Jati Adivasi Nyaya Maha Abhiyan (PM-JANMAN)' scheme is primarily aimed at:",
        "Option1": "Providing universal basic income to all tribal families.",
        "Option2": "Establishing Eklavya Model Residential Schools (EMRS) in every block.",
        "Option3": "Saturating Particularly Vulnerable Tribal Groups (PVTGs) with basic facilities.",
        "Option4": "Promoting tourism in tribal-dominated areas.",
        "Correct Option": "Saturating Particularly Vulnerable Tribal Groups (PVTGs) with basic facilities."
    },
    {
        "Question": "With reference to the Inter-State Council in India, consider the following statements:\n1. It is a constitutional body established under Article 263.\n2. The Prime Minister is the Chairman of the Council.\n3. Its recommendations are binding on the Union and State Governments.\nWhich of the statements given above is/are correct?",
        "Option1": "1 only",
        "Option2": "1 and 2 only",
        "Option3": "2 and 3 only",
        "Option4": "1, 2 and 3",
        "Correct Option": "1 and 2 only"
    },
    {
        "Question": "Which is the nodal ministry for implementing the PM Vishwakarma Scheme?",
        "Option1": "Ministry of Skill Development and Entrepreneurship",
        "Option2": "Ministry of Finance",
        "Option3": "Ministry of Culture",
        "Option4": "Ministry of Micro, Small and Medium Enterprises (MSME) (along with others)",
        "Correct Option": "Ministry of Micro, Small and Medium Enterprises (MSME) (along with others)"
    },
    {
        "Question": "The recent judgment by the Supreme Court on the appointment of the Chief Election Commissioner (CEC) and Election Commissioners (ECs) proposed a committee comprising:",
        "Option1": "Prime Minister, Chief Justice of India, and Leader of Opposition in Lok Sabha.",
        "Option2": "Prime Minister, Union Home Minister, and Leader of Opposition in Lok Sabha.",
        "Option3": "Prime Minister, Leader of Opposition in Lok Sabha, and a Union Cabinet Minister. (As per the new law passed by Parliament)",
        "Option4": "Chief Justice of India, Leader of Opposition in Lok Sabha, and the Law Minister.",
        "Correct Option": "Prime Minister, Leader of Opposition in Lok Sabha, and a Union Cabinet Minister. (As per the new law passed by Parliament)"
    },
    {
        "Question": "The 'Disinvestment Target' of the Government of India is published annually as part of:",
        "Option1": "The Economic Survey.",
        "Option2": "The Finance Commission Report.",
        "Option3": "The Union Budget.",
        "Option4": "The RBI's Monetary Policy Report.",
        "Correct Option": "The Union Budget."
    },
    {
        "Question": "The GI tag (Geographical Indicator) for the 'Basmati Rice' variety is exclusively shared between India and which other country?",
        "Option1": "Afghanistan",
        "Option2": "Iran",
        "Option3": "Nepal",
        "Option4": "Pakistan",
        "Correct Option": "Pakistan"
    },
    {
        "Question": "The 'Right to Repair' framework, recently in news, is an initiative primarily focused on:",
        "Option1": "Ensuring consumers have access to tools and information to fix their products.",
        "Option2": "Providing the right to free repair for electronic goods.",
        "Option3": "Establishing government-run repair centers.",
        "Option4": "Mandating manufacturers to replace faulty products within the warranty period.",
        "Correct Option": "Ensuring consumers have access to tools and information to fix their products."
    },
    {
        "Question": "The 'Mahila Samman Savings Certificate (MSSC)' scheme is designed to:",
        "Option1": "Provide educational loans to girl students.",
        "Option2": "Offer a small savings deposit facility for women and girls.",
        "Option3": "Provide collateral-free loans to women entrepreneurs.",
        "Option4": "Fund the setting up of self-help groups (SHGs).",
        "Correct Option": "Offer a small savings deposit facility for women and girls."
    },
    {
        "Question": "The 'Operation Kaveri', recently conducted by India, was related to:",
        "Option1": "Evacuating Indian citizens from Ukraine.",
        "Option2": "Rescue and relief operations after the Turkiye-Syria earthquake.",
        "Option3": "Evacuating Indian citizens from conflict-ridden Sudan.",
        "Option4": "Providing humanitarian assistance to Afghanistan.",
        "Correct Option": "Evacuating Indian citizens from conflict-ridden Sudan."
    },
    {
        "Question": "The 'Global Partnership on Artificial Intelligence (GPAI)', a multi-stakeholder initiative, is headquartered in:",
        "Option1": "New York",
        "Option2": "Geneva",
        "Option3": "Bengaluru",
        "Option4": "Paris",
        "Correct Option": "Paris"
    },
    {
        "Question": "The 'First in Health' initiative, launched in collaboration with the World Economic Forum (WEF), focuses on:",
        "Option1": "Universal access to COVID-19 vaccines.",
        "Option2": "Integrating environmental protection with healthcare policy.",
        "Option3": "Digital transformation of the healthcare sector.",
        "Option4": "Addressing the challenges of non-communicable diseases (NCDs).",
        "Correct Option": "Digital transformation of the healthcare sector."
    },
    {
        "Question": "Which is the first country to issue a Digital Permanent Residency Visa (DPRV) for remote workers?",
        "Option1": "USA",
        "Option2": "UAE",
        "Option3": "Indonesia",
        "Option4": "Estonia",
        "Correct Option": "Indonesia"
    },
    {
        "Question": "The 'Teesta River' dispute, often in news, is a point of contention between India and which country?",
        "Option1": "Nepal",
        "Option2": "Bhutan",
        "Option3": "China",
        "Option4": "Bangladesh",
        "Correct Option": "Bangladesh"
    },
    {
        "Question": "Which major UN body recently voted to replace the UNWTO (World Tourism Organization) with the 'UN Tourism' name and mandate?",
        "Option1": "UN General Assembly",
        "Option2": "UN Security Council",
        "Option3": "World Tourism Organization General Assembly",
        "Option4": "UN Economic and Social Council (ECOSOC)",
        "Correct Option": "World Tourism Organization General Assembly"
    },
    {
        "Question": "Zaporizhzhia Nuclear Power Plant, the largest in Europe, which was in news due to the Russia-Ukraine conflict, is located in:",
        "Option1": "Russia",
        "Option2": "Belarus",
        "Option3": "Poland",
        "Option4": "Ukraine",
        "Correct Option": "Ukraine"
    },
    {
        "Question": "India's first G20 summit after acquiring permanent membership in the African Union was hosted in:",
        "Option1": "Bali",
        "Option2": "Osaka",
        "Option3": "New Delhi",
        "Option4": "Rio de Janeiro",
        "Correct Option": "New Delhi"
    },
    {
        "Question": "The 'Sovereign Green Bond (SGrB)' framework, recently issued by the Government of India, aims to finance:",
        "Option1": "Social security schemes and public welfare programs.",
        "Option2": "Infrastructure projects in the North Eastern Region.",
        "Option3": "Projects promoting green and climate-friendly initiatives.",
        "Option4": "Funding for defense capital procurement.",
        "Correct Option": "Projects promoting green and climate-friendly initiatives."
    },
    {
        "Question": "The 'Unified Payments Interface (UPI)' has recently been linked with the fast payment system of which country for cross-border transactions?",
        "Option1": "USA",
        "Option2": "Singapore (PayNow)",
        "Option3": "Australia",
        "Option4": "UK",
        "Correct Option": "Singapore (PayNow)"
    },
    {
        "Question": "The term 'Basel III norms', often discussed in the financial sector, is primarily related to the regulation of:",
        "Option1": "Insurance companies",
        "Option2": "Non-Banking Financial Companies (NBFCs)",
        "Option3": "Banks",
        "Option4": "Stock exchanges",
        "Correct Option": "Banks"
    },
    {
        "Question": "Which of the following is NOT a component of the RBI's Foreign Exchange Reserves?",
        "Option1": "Foreign Currency Assets (FCA)",
        "Option2": "Gold",
        "Option3": "External Commercial Borrowings (ECBs)",
        "Option4": "Special Drawing Rights (SDRs) (with IMF)",
        "Correct Option": "External Commercial Borrowings (ECBs)"
    },
    {
        "Question": "The 'Minimum Support Price (MSP)' for crops is announced by the Government of India based on the recommendations of which body?",
        "Option1": "NITI Aayog",
        "Option2": "Commission for Agricultural Costs and Prices (CACP)",
        "Option3": "Ministry of Finance",
        "Option4": "National Bank for Agriculture and Rural Development (NABARD)",
        "Correct Option": "Commission for Agricultural Costs and Prices (CACP)"
    },
    {
        "Question": "With reference to the National Statistical Office (NSO), consider the following statements:\n1. It is the nodal agency for conducting the Population Census in India.\n2. It releases the Gross Domestic Product (GDP) estimates for India.\nWhich of the statements given above is/are correct?",
        "Option1": "1 only",
        "Option2": "2 only",
        "Option3": "Both 1 and 2",
        "Option4": "Neither 1 nor 2",
        "Correct Option": "2 only"
    },
    {
        "Question": "The 'Agri Stack' initiative of the Government of India is related to:",
        "Option1": "A platform for online trading of agricultural commodities.",
        "Option2": "A digital ecosystem for the farm sector using a unique farmer ID.",
        "Option3": "A storage system for buffer stock of food grains.",
        "Option4": "An insurance scheme for farm machinery.",
        "Correct Option": "A digital ecosystem for the farm sector using a unique farmer ID."
    },
    {
        "Question": "The term 'Inflation Target' in the context of Indian monetary policy is set by the Government of India in consultation with the:",
        "Option1": "Securities and Exchange Board of India (SEBI)",
        "Option2": "Ministry of Finance",
        "Option3": "Reserve Bank of India (RBI)",
        "Option4": "NITI Aayog",
        "Correct Option": "Reserve Bank of India (RBI)"
    },
    {
        "Question": "Priority Sector Lending (PSL) guidelines by the RBI primarily ensure that:",
        "Option1": "Banks lend only to the public sector undertakings.",
        "Option2": "Commercial banks give a minimum percentage of their credit to certain sectors.",
        "Option3": "Non-Performing Assets (NPAs) are kept below a specified limit.",
        "Option4": "Banks maintain sufficient cash reserves.",
        "Correct Option": "Commercial banks give a minimum percentage of their credit to certain sectors."
    },
    {
        "Question": "The 'National Logistics Policy', launched recently, aims to:",
        "Option1": "Reduce logistics cost as a percentage of GDP.",
        "Option2": "Improve the country's ranking in the Logistics Performance Index (LPI).",
        "Option3": "Promote multimodal transportation.",
        "Option4": "All of the above",
        "Correct Option": "All of the above"
    },
    {
        "Question": "What is the primary focus of the 'Bharat 6G Alliance (B6GA)'?",
        "Option1": "Developing satellites for 6G connectivity.",
        "Option2": "Driving innovation and collaboration in 6G technology.",
        "Option3": "Setting up 6G spectrum auctions.",
        "Option4": "Regulating the use of 6G devices.",
        "Correct Option": "Driving innovation and collaboration in 6G technology."
    },
    {
        "Question": "Which institution is the custodian of the National Industrial Corridor Development and Implementation Trust (NICDIT)?",
        "Option1": "Ministry of Commerce and Industry",
        "Option2": "Ministry of Finance",
        "Option3": "NITI Aayog",
        "Option4": "Ministry of Housing and Urban Affairs",
        "Correct Option": "Ministry of Commerce and Industry"
    },
    {
        "Question": "The 'Emergency Credit Line Guarantee Scheme (ECLGS)' was primarily launched to support:",
        "Option1": "Large industrial conglomerates.",
        "Option2": "Micro, Small and Medium Enterprises (MSMEs) during the COVID-19 pandemic.",
        "Option3": "The agriculture sector.",
        "Option4": "Export-oriented units.",
        "Correct Option": "Micro, Small and Medium Enterprises (MSMEs) during the COVID-19 pandemic."
    },
    {
        "Question": "'Blue Economy' primarily refers to the sustainable use of which resource for economic growth?",
        "Option1": "Renewable energy resources",
        "Option2": "Minerals",
        "Option3": "Ocean resources",
        "Option4": "Forest resources",
        "Correct Option": "Ocean resources"
    },
    {
        "Question": "Which index, published by the World Economic Forum (WEF), measures the impact of economic policies and institutions on the environment?",
        "Option1": "Human Development Index (HDI)",
        "Option2": "Global Competitiveness Index",
        "Option3": "Environmental Performance Index (EPI)",
        "Option4": "Global Innovation Index",
        "Correct Option": "Environmental Performance Index (EPI)"
    },
    {
        "Question": "The 'Carbon Border Adjustment Mechanism (CBAM)', recently in news, is an initiative proposed by:",
        "Option1": "USA",
        "Option2": "China",
        "Option3": "European Union (EU)",
        "Option4": "India",
        "Correct Option": "European Union (EU)"
    },
    {
        "Question": "The 'Operation Dost' was India's humanitarian assistance effort aimed at which country/countries hit by a massive earthquake?",
        "Option1": "Pakistan",
        "Option2": "Iran",
        "Option3": "Turkiye and Syria",
        "Option4": "Nepal",
        "Correct Option": "Turkiye and Syria"
    },
    {
        "Question": "The 'Quad' group of nations comprises India, USA, Japan, and:",
        "Option1": "Germany",
        "Option2": "France",
        "Option3": "Australia",
        "Option4": "South Korea",
        "Correct Option": "Australia"
    },
    {
        "Question": "Which is the latest country to be admitted as a permanent member of the BRICS group?",
        "Option1": "Indonesia",
        "Option2": "Nigeria",
        "Option3": "Egypt (among others, as of latest expansion)",
        "Option4": "Turkey",
        "Correct Option": "Egypt (among others, as of latest expansion)"
    },
    {
        "Question": "The 'IMEC' (India-Middle East-Europe Economic Corridor), discussed at the G20 summit, is a potential alternative to which major Chinese initiative?",
        "Option1": "Asian Infrastructure Investment Bank (AIIB)",
        "Option2": "Belt and Road Initiative (BRI)",
        "Option3": "Digital Silk Road",
        "Option4": "Shanghai Cooperation Organisation (SCO)",
        "Correct Option": "Belt and Road Initiative (BRI)"
    },
    {
        "Question": "The 'Suez Canal', a crucial choke point for global trade, connects the Mediterranean Sea with the:",
        "Option1": "Black Sea",
        "Option2": "Caspian Sea",
        "Option3": "Red Sea",
        "Option4": "Arabian Sea",
        "Correct Option": "Red Sea"
    },
    {
        "Question": "The 'Global Minimum Tax' framework (Pillar Two) is primarily aimed at preventing:",
        "Option1": "Tax evasion by individuals.",
        "Option2": "Base Erosion and Profit Shifting (BEPS) by multinational corporations.",
        "Option3": "Money laundering by offshore entities.",
        "Option4": "Currency manipulation by central banks.",
        "Correct Option": "Base Erosion and Profit Shifting (BEPS) by multinational corporations."
    },
    {
        "Question": "The 'Mission LiFE' (Lifestyle for Environment) is an India-led global mass movement aimed at promoting:",
        "Option1": "The use of electric vehicles only.",
        "Option2": "Sustainable and climate-friendly behavior by individuals.",
        "Option3": "Afforestation in arid and semi-arid zones.",
        "Option4": "Switching to renewable energy sources at the national level.",
        "Correct Option": "Sustainable and climate-friendly behavior by individuals."
    },
    {
        "Question": "The 'Net Zero' target for carbon emissions for India is set for the year:",
        "Option1": "2030",
        "Option2": "2040",
        "Option3": "2050",
        "Option4": "2070",
        "Correct Option": "2070"
    },
    {
        "Question": "Which of the following is the largest source of India's commercial energy consumption?",
        "Option1": "Natural Gas",
        "Option2": "Hydro Power",
        "Option3": "Coal",
        "Option4": "Solar and Wind",
        "Correct Option": "Coal"
    },
    {
        "Question": "The 'NISAR' project, a joint Earth observation satellite mission, is a collaboration between ISRO and which other space agency?",
        "Option1": "European Space Agency (ESA)",
        "Option2": "Japan Aerospace Exploration Agency (JAXA)",
        "Option3": "Roscosmos (Russia)",
        "Option4": "NASA (USA)",
        "Correct Option": "NASA (USA)"
    },
    {
        "Question": "'BHAROS', recently launched by the IIT Madras, is India's indigenous alternative to which operating system?",
        "Option1": "Windows",
        "Option2": "iOS",
        "Option3": "Android",
        "Option4": "Linux",
        "Correct Option": "Android"
    },
    {
        "Question": "Which of the following is the launch vehicle used for the Chandrayaan-3 mission?",
        "Option1": "PSLV-C54",
        "Option2": "GSLV Mk III (LVM3)",
        "Option3": "SSLV-D2",
        "Option4": "PSLV XL",
        "Correct Option": "GSLV Mk III (LVM3)"
    },
    {
        "Question": "The 'Aditya-L1 Mission', India's first space-based observatory to study the Sun, will be placed in a Halo orbit around which Lagrange point (L point)?",
        "Option1": "L2",
        "Option2": "L3",
        "Option3": "L4",
        "Option4": "L1",
        "Correct Option": "L1"
    },
    {
        "Question": "'Nipah Virus', which recently caused an outbreak in India, is a type of:",
        "Option1": "Bacterium",
        "Option2": "Fungus",
        "Option3": "RNA Virus",
        "Option4": "Protozoa",
        "Correct Option": "RNA Virus"
    },
    {
        "Question": "'Project CHETAK', often seen in defense news, is related to the upgrade of which helicopter fleet of the Indian Armed Forces?",
        "Option1": "Mi-17",
        "Option2": "ALH Dhruv",
        "Option3": "Cheetah and Chetak",
        "Option4": "Rudra",
        "Correct Option": "Cheetah and Chetak"
    },
    {
        "Question": "'Deep Ocean Mission (DOM)' of the Government of India primarily focuses on:",
        "Option1": "Exploring the potential of tidal energy.",
        "Option2": "Developing a national deep-sea fishing policy.",
        "Option3": "Exploring deep-sea resources and developing deep-sea technology.",
        "Option4": "Mapping the Exclusive Economic Zone (EEZ) for oil and gas.",
        "Correct Option": "Exploring deep-sea resources and developing deep-sea technology."
    },
    {
        "Question": "The term 'Quantum Entanglement', a key concept in quantum computing, refers to:",
        "Option1": "The speed at which quantum computers process data.",
        "Option2": "A phenomenon where two quantum particles are linked and share the same fate, regardless of distance.",
        "Option3": "The maximum number of qubits a quantum computer can handle.",
        "Option4": "The method used to cool quantum chips to near-absolute zero.",
        "Correct Option": "A phenomenon where two quantum particles are linked and share the same fate, regardless of distance."
    },
    {
        "Question": "Which Indian institution recently launched a first-of-its-kind DNA Database for identifying unidentified bodies?",
        "Option1": "AIIMS, New Delhi",
        "Option2": "ICMR (Indian Council of Medical Research)",
        "Option3": "National Crime Records Bureau (NCRB)",
        "Option4": "Forensic Science Laboratory (FSL), Delhi",
        "Correct Option": "National Crime Records Bureau (NCRB)"
    },
    {
        "Question": "The newly developed 'Indigenous Light Combat Helicopter (LCH)' of the Indian Air Force has been named:",
        "Option1": "Dhruv",
        "Option2": "Prachand",
        "Option3": "Tejas",
        "Option4": "Rudra",
        "Correct Option": "Prachand"
    },
    {
        "Question": "'Hyperloop' technology, often in news, is a proposed mode of transport that works by:",
        "Option1": "Using magnetic levitation in a vacuum-sealed tube.",
        "Option2": "High-speed rail on dedicated elevated tracks.",
        "Option3": "Solar-powered electric trains.",
        "Option4": "Autonomous drone-based delivery system.",
        "Correct Option": "Using magnetic levitation in a vacuum-sealed tube."
    },
    {
        "Question": "The 'Gaganyaan Mission' aims to send astronauts into which orbital trajectory?",
        "Option1": "Geosynchronous Orbit (GEO)",
        "Option2": "Medium Earth Orbit (MEO)",
        "Option3": "Low Earth Orbit (LEO)",
        "Option4": "Lunar Orbit",
        "Correct Option": "Low Earth Orbit (LEO)"
    },
    {
        "Question": "'Li-Fi' technology, considered an alternative to Wi-Fi, uses which medium for data transmission?",
        "Option1": "Radio waves",
        "Option2": "Microwaves",
        "Option3": "Infrared radiation",
        "Option4": "Visible Light",
        "Correct Option": "Visible Light"
    },
    {
        "Question": "'Mission Indradhanush' of the Government of India is related to:",
        "Option1": "Electrification of rural areas.",
        "Option2": "Financial inclusion.",
        "Option3": "Immunization of children and pregnant women.",
        "Option4": "Clean drinking water supply.",
        "Correct Option": "Immunization of children and pregnant women."
    },
    {
        "Question": "The first indigenous Nuclear Powered Ballistic Missile Submarine (SSBN) of India is:",
        "Option1": "INS Vikramaditya",
        "Option2": "INS Khanderi",
        "Option3": "INS Arihant",
        "Option4": "INS Kalvari",
        "Correct Option": "INS Arihant"
    },
    {
        "Question": "'DART Mission' (Double Asteroid Redirection Test), which was in the news for successfully impacting an asteroid, was a project of:",
        "Option1": "ISRO",
        "Option2": "ESA",
        "Option3": "JAXA",
        "Option4": "NASA",
        "Correct Option": "NASA"
    },
    {
        "Question": "The Defence Acquisition Procedure (DAP) 2020 lays special emphasis on:",
        "Option1": "Increasing defense exports to 10 billion USD.",
        "Option2": "Promoting joint military exercises with NATO countries.",
        "Option3": "Boosting indigenous defense manufacturing (Aatmanirbhar Bharat).",
        "Option4": "Reducing the size of the armed forces.",
        "Correct Option": "Boosting indigenous defense manufacturing (Aatmanirbhar Bharat)."
    },
    {
        "Question": "'e-Sanjeevani' is a national telemedicine service platform developed by which ministry?",
        "Option1": "Ministry of IT",
        "Option2": "Ministry of Health and Family Welfare",
        "Option3": "Ministry of Rural Development",
        "Option4": "Ministry of Education",
        "Correct Option": "Ministry of Health and Family Welfare"
    },
    {
        "Question": "The recently discovered 'Webb's Law' in Physics is primarily related to:",
        "Option1": "The expansion of the universe.",
        "Option2": "The behavior of light in a vacuum.",
        "Option3": "The physics of animal and insect locomotion (walking and running).",
        "Option4": "Quantum computing algorithms.",
        "Correct Option": "The physics of animal and insect locomotion (walking and running)."
    },
    {
        "Question": "'Vande Bharat Mission' was an initiative of the Government of India to:",
        "Option1": "Promote tourism to cultural sites.",
        "Option2": "Repatriate stranded Indian citizens from abroad during the COVID-19 pandemic.",
        "Option3": "Launch high-speed rail services.",
        "Option4": "Provide educational scholarships for non-resident Indians (NRIs).",
        "Correct Option": "Repatriate stranded Indian citizens from abroad during the COVID-19 pandemic."
    },
    {
        "Question": "'Operation Samudra Setu' was a Naval exercise focusing on:",
        "Option1": "Joint maritime security patrol with Quad countries.",
        "Option2": "Anti-piracy operations in the Gulf of Aden.",
        "Option3": "Repatriating Indian citizens from foreign countries during COVID-19 using naval ships.",
        "Option4": "Disaster relief in the Indian Ocean Region.",
        "Correct Option": "Repatriating Indian citizens from foreign countries during COVID-19 using naval ships."
    },
    {
        "Question": "The Indian Government is planning to develop a 'Semiconductor Ecosystem' in India with a focus on:",
        "Option1": "Chip designing only.",
        "Option2": "Assembly, Test, Marking, and Packaging (ATMP) only.",
        "Option3": "Fabrication (FAB) units only.",
        "Option4": "A complete value chain from design to FAB and ATMP.",
        "Correct Option": "A complete value chain from design to FAB and ATMP."
    },
    {
        "Question": "The 'Small Satellite Launch Vehicle (SSLV)' developed by ISRO is primarily designed for:",
        "Option1": "Launching heavy communication satellites.",
        "Option2": "Launching small satellites on demand to LEO (Low Earth Orbit).",
        "Option3": "Interplanetary missions.",
        "Option4": "Launching crewed missions.",
        "Correct Option": "Launching small satellites on demand to LEO (Low Earth Orbit)."
    },
    {
        "Question": "The term 'Web 3.0' is most accurately associated with:",
        "Option1": "Cloud computing.",
        "Option2": "Centralized server systems.",
        "Option3": "Decentralized internet built on blockchain technology.",
        "Option4": "Mobile-first internet architecture.",
        "Correct Option": "Decentralized internet built on blockchain technology."
    },
    {
        "Question": "Which is the largest Science Museum network in India, operating under the Ministry of Culture?",
        "Option1": "Salar Jung Museum, Hyderabad",
        "Option2": "National Council of Science Museums (NCSM)",
        "Option3": "National Museum, New Delhi",
        "Option4": "Indian Museum, Kolkata",
        "Correct Option": "National Council of Science Museums (NCSM)"
    },
    {
        "Question": "Which of the following is the world's first living heritage university, recently given the UNESCO heritage tag?",
        "Option1": "Nalanda University",
        "Option2": "Visva-Bharati University",
        "Option3": "University of Oxford",
        "Option4": "Jawaharlal Nehru University",
        "Correct Option": "Visva-Bharati University"
    },
    {
        "Question": "The 'Similipal Biosphere Reserve', recently in news for its unique black tiger population, is located in which state?",
        "Option1": "West Bengal",
        "Option2": "Assam",
        "Option3": "Madhya Pradesh",
        "Option4": "Odisha",
        "Correct Option": "Odisha"
    },
    {
        "Question": "The 'Global Biodiversity Framework (GBF)', adopted at COP15 of the CBD (Convention on Biological Diversity), is also known as:",
        "Option1": "Paris Agreement for Biodiversity",
        "Option2": "Kunming-Montreal Agreement",
        "Option3": "Nagoya Protocol",
        "Option4": "Aichi Targets",
        "Correct Option": "Kunming-Montreal Agreement"
    },
    {
        "Question": "The term 'Blue Hole', recently discovered in the Yucatan Peninsula, is a type of:",
        "Option1": "Deep-sea trench",
        "Option2": "Oceanic volcano",
        "Option3": "Underwater sinkhole",
        "Option4": "Submarine canyon",
        "Correct Option": "Underwater sinkhole"
    },
    {
        "Question": "The 'Global Stocktake (GST)', a term frequently used in climate change negotiations, is related to the periodic review of the implementation of the:",
        "Option1": "Kyoto Protocol",
        "Option2": "Montreal Protocol",
        "Option3": "Paris Agreement",
        "Option4": "Rio Declaration",
        "Correct Option": "Paris Agreement"
    },
    {
        "Question": "The United Nations Climate Change Conference (COP28) was held in:",
        "Option1": "Sharm El Sheikh, Egypt",
        "Option2": "Glasgow, UK",
        "Option3": "Dubai, UAE",
        "Option4": "Bonn, Germany",
        "Correct Option": "Dubai, UAE"
    },
    {
        "Question": "'Pusa Basmati 1847', often mentioned in agricultural news, is a new variety developed to be resistant to:",
        "Option1": "Drought and salinity",
        "Option2": "Pests and fungi",
        "Option3": "Blight and blast diseases",
        "Option4": "High temperatures",
        "Correct Option": "Blight and blast diseases"
    },
    {
        "Question": "The 'Great Nicobar Project', which involves significant infrastructure development, is located near which UNESCO Biosphere Reserve?",
        "Option1": "Sunderbans",
        "Option2": "Gulf of Mannar",
        "Option3": "Great Nicobar",
        "Option4": "Nilgiri",
        "Correct Option": "Great Nicobar"
    },
    {
        "Question": "Which of the following is a marine mammal that was recently designated as a State Aquatic Animal of Uttar Pradesh?",
        "Option1": "Gangetic Shark",
        "Option2": "Smooth-coated Otter",
        "Option3": "Gangetic Dolphin",
        "Option4": "Irrawaddy Dolphin",
        "Correct Option": "Gangetic Dolphin"
    },
    {
        "Question": "The 'International Big Cat Alliance (IBCA)', launched by India, aims at the conservation of how many major Big Cat species?",
        "Option1": "Five",
        "Option2": "Six",
        "Option3": "Seven",
        "Option4": "Ten",
        "Correct Option": "Seven"
    },
    {
        "Question": "The 'Global Ramsar City Accreditation' is associated with the conservation of:",
        "Option1": "Forests",
        "Option2": "Deserts",
        "Option3": "Coral Reefs",
        "Option4": "Wetlands",
        "Correct Option": "Wetlands"
    },
    {
        "Question": "'Project Seabird', a naval infrastructure project, is being developed at which location?",
        "Option1": "Vishakhapatnam",
        "Option2": "Kochi",
        "Option3": "Karwar (Karnataka)",
        "Option4": "Mumbai",
        "Correct Option": "Karwar (Karnataka)"
    },
    {
        "Question": "The 'EIA' (Environmental Impact Assessment) Notification in India is issued under which Act?",
        "Option1": "Water (Prevention and Control of Pollution) Act, 1974",
        "Option2": "Environment (Protection) Act, 1986",
        "Option3": "Wildlife (Protection) Act, 1972",
        "Option4": "Forest (Conservation) Act, 1980",
        "Correct Option": "Environment (Protection) Act, 1986"
    },
    {
        "Question": "The 'Global Methane Pledge', a voluntary agreement, primarily aims to reduce methane emissions from which two major sectors?",
        "Option1": "Energy and Transport",
        "Option2": "Industry and Waste",
        "Option3": "Fossil fuels and Agriculture",
        "Option4": "Forestry and Cement",
        "Correct Option": "Fossil fuels and Agriculture"
    },
    {
        "Question": "The recently restored 'Karakoram Pass', a high mountain pass, is located in the region disputed between India and:",
        "Option1": "Nepal",
        "Option2": "Bhutan",
        "Option3": "China (Aksai Chin)",
        "Option4": "Pakistan",
        "Correct Option": "China (Aksai Chin)"
    },
    {
        "Question": "'Sattriya', one of the 8 classical dances of India, is associated with which state?",
        "Option1": "Manipur",
        "Option2": "Odisha",
        "Option3": "Assam",
        "Option4": "Kerala",
        "Correct Option": "Assam"
    },
    {
        "Question": "The 'UNESCO World Heritage Site' of Konark Sun Temple is located in:",
        "Option1": "Tamil Nadu",
        "Option2": "Karnataka",
        "Option3": "West Bengal",
        "Option4": "Odisha",
        "Correct Option": "Odisha"
    },
    {
        "Question": "The term 'Agroforestry' is a sustainable land-use system that primarily combines trees and shrubs with:",
        "Option1": "Only livestock",
        "Option2": "Only crop cultivation",
        "Option3": "Both agricultural crops and livestock",
        "Option4": "Only commercial forestry",
        "Correct Option": "Both agricultural crops and livestock"
    },
    {
        "Question": "The 'National Disaster Response Force (NDRF)' operates under the administrative control of which ministry?",
        "Option1": "Ministry of Defense",
        "Option2": "Ministry of Home Affairs",
        "Option3": "Ministry of Environment, Forest and Climate Change",
        "Option4": "Ministry of Social Justice and Empowerment",
        "Correct Option": "Ministry of Home Affairs"
    },
    {
        "Question": "The 'Panchamrut' commitments, announced by India at COP26, are related to:",
        "Option1": "Sustainable water management.",
        "Option2": "Climate action and emission reduction targets.",
        "Option3": "Biodiversity conservation.",
        "Option4": "Financial aid to developing nations.",
        "Correct Option": "Climate action and emission reduction targets."
    },
    {
        "Question": "The term 'Inversion of Control' in the context of environment refers to:",
        "Option1": "A method for managing pollution at the source.",
        "Option2": "A system for distributing carbon credits.",
        "Option3": "An atmospheric phenomenon where temperature increases with altitude, trapping pollutants.",
        "Option4": "Reversal of the Earth's magnetic poles.",
        "Correct Option": "An atmospheric phenomenon where temperature increases with altitude, trapping pollutants."
    },
    {
        "Question": "The 'Kafala System', a sponsorship system for migrant workers recently replaced by Saudi Arabia, was primarily criticized for:",
        "Option1": "Promoting illegal immigration.",
        "Option2": "High visa fees for workers.",
        "Option3": "Allowing employers extensive control over workers' residency and employment.",
        "Option4": "Restricting workers from bringing their families.",
        "Correct Option": "Allowing employers extensive control over workers' residency and employment."
    },
    {
        "Question": "The 'Black Sea Grain Initiative', recently suspended, was an agreement brokered by Turkey and the UN to facilitate the export of food grains from which country?",
        "Option1": "Russia",
        "Option2": "Kazakhstan",
        "Option3": "Ukraine",
        "Option4": "Iran",
        "Correct Option": "Ukraine"
    },
    {
        "Question": "The 'Indra' joint military exercise is conducted between India and which country?",
        "Option1": "USA",
        "Option2": "France",
        "Option3": "Russia",
        "Option4": "Japan",
        "Correct Option": "Russia"
    },
    {
        "Question": "The annual 'World Economic Situation and Prospects (WESP)' report is released by:",
        "Option1": "World Bank",
        "Option2": "International Monetary Fund (IMF)",
        "Option3": "United Nations (UN)",
        "Option4": "World Economic Forum (WEF)",
        "Correct Option": "United Nations (UN)"
    },
    {
        "Question": "Which international organization recently introduced the 'Global Shield' initiative to provide financial protection against climate-related disasters?",
        "Option1": "G7",
        "Option2": "G20",
        "Option3": "UNEP",
        "Option4": "World Bank",
        "Correct Option": "G7"
    },
    {
        "Question": "The 'DigiLocker' service is managed by which of the following organizations?",
        "Option1": "UIDAI",
        "Option2": "Ministry of Electronics and Information Technology (MeitY)",
        "Option3": "National Informatics Centre (NIC)",
        "Option4": "National Payment Corporation of India (NPCI)",
        "Correct Option": "Ministry of Electronics and Information Technology (MeitY)"
    },
    {
        "Question": "Which country recently became the 8th member of the South Asian Association for Regional Cooperation (SAARC)?",
        "Option1": "Nepal",
        "Option2": "Bhutan",
        "Option3": "Afghanistan",
        "Option4": "Myanmar",
        "Correct Option": "Afghanistan"
    },
    {
        "Question": "The term 'Dark Pattern' is associated with:",
        "Option1": "Cyber warfare strategies.",
        "Option2": "Unethical user interface design that misleads consumers.",
        "Option3": "A new material for solar panels.",
        "Option4": "A type of deep-sea biological phenomenon.",
        "Correct Option": "Unethical user interface design that misleads consumers."
    },
    {
        "Question": "India's first Indigenous Aircraft Carrier (IAC-1) was recently commissioned and named as:",
        "Option1": "INS Kolkata",
        "Option2": "INS Chennai",
        "Option3": "INS Vikrant",
        "Option4": "INS Visakhapatnam",
        "Correct Option": "INS Vikrant"
    },
    {
        "Question": "The 'PLI (Production Linked Incentive) Scheme' is aimed at boosting domestic manufacturing in which of the following sectors?",
        "Option1": "Automobiles and Auto Components",
        "Option2": "Telecom and Networking Products",
        "Option3": "White Goods (ACs and LEDs)",
        "Option4": "All of the above",
        "Correct Option": "All of the above"
    },
    {
        "Question": "Which article of the Indian Constitution, recently discussed in the context of the Delhi government's administrative control, deals with special provisions for the National Capital Territory of Delhi?",
        "Option1": "Article 239AA",
        "Option2": "Article 246",
        "Option3": "Article 280",
        "Option4": "Article 370",
        "Correct Option": "Article 239AA"
    },
    {
        "Question": "The 'Green Hydrogen Mission' of India aims to achieve which of the following targets?",
        "Option1": "To increase renewable energy capacity to 500 GW by 2030.",
        "Option2": "To produce 5 million tonnes of Green Hydrogen annually by 2030.",
        "Option3": "To achieve Net Zero emissions by 2047.",
        "Option4": "To become the largest exporter of Blue Hydrogen.",
        "Correct Option": "To produce 5 million tonnes of Green Hydrogen annually by 2030."
    },
    {
        "Question": "Which state's government recently passed a law that reserves 75% of private sector jobs for local youth?",
        "Option1": "Maharashtra",
        "Option2": "Karnataka",
        "Option3": "Haryana",
        "Option4": "Tamil Nadu",
        "Correct Option": "Haryana"
    },
    {
        "Question": "The term 'Critical Minerals' in the context of India's policy is important for which of the following industries?",
        "Option1": "Renewable Energy (Solar, Wind)",
        "Option2": "Electric Vehicles and Batteries",
        "Option3": "Defence and Aerospace",
        "Option4": "All of the above",
        "Correct Option": "All of the above"
    },
    {
        "Question": "The 'Mizoram-Tripura-Bangladesh (MTB) Corridor' aims to connect the North-East with Bangladesh via which mode of transport?",
        "Option1": "Air connectivity",
        "Option2": "Rail connectivity",
        "Option3": "Waterways and Road",
        "Option4": "Pipeline for petroleum products",
        "Correct Option": "Waterways and Road"
    },
    {
        "Question": "Which of the following is the host nation for the upcoming Summer Olympic Games in 2024?",
        "Option1": "Los Angeles, USA",
        "Option2": "Brisbane, Australia",
        "Option3": "Paris, France",
        "Option4": "Tokyo, Japan",
        "Correct Option": "Paris, France"
    },
    {
        "Question": "The 'India Semiconductor Mission (ISM)' operates under the administrative control of which Ministry?",
        "Option1": "Ministry of Commerce and Industry",
        "Option2": "Ministry of Heavy Industries",
        "Option3": "Ministry of Electronics and Information Technology (MeitY)",
        "Option4": "Ministry of Science and Technology",
        "Correct Option": "Ministry of Electronics and Information Technology (MeitY)"
    },
    {
        "Question": "Which Indian city was recently added to the UNESCO Creative Cities Network in the field of Literature?",
        "Option1": "Varanasi",
        "Option2": "Gwalior",
        "Option3": "Kozhikode",
        "Option4": "Jaipur",
        "Correct Option": "Kozhikode"
    },
    {
        "Question": "The 'Chabahar Port', which is strategically important for India's trade with Afghanistan and Central Asia, is located in which country?",
        "Option1": "Pakistan",
        "Option2": "Oman",
        "Option3": "Iran",
        "Option4": "UAE",
        "Correct Option": "Iran"
    },
    {
        "Question": "The 'Asian Development Bank (ADB)' has its headquarters in:",
        "Option1": "Tokyo, Japan",
        "Option2": "Beijing, China",
        "Option3": "Manila, Philippines",
        "Option4": "Seoul, South Korea",
        "Correct Option": "Manila, Philippines"
    },
    {
        "Question": "What is 'Samudra Gupta' (not the historical figure), recently seen in news related to the Indian Navy?",
        "Option1": "A new naval base in the Andaman Islands.",
        "Option2": "A high-tech surveillance drone.",
        "Option3": "India's first underwater metro project.",
        "Option4": "The new nomenclature for the Indian Ocean Region's security strategy.",
        "Correct Option": "The new nomenclature for the Indian Ocean Region's security strategy."
    },
    {
        "Question": "The 'P $\text{M}$ $\text{Kisan}$ $\text{Samman}$ $\text{Nidhi}$' scheme is a central sector scheme that provides:",
        "Option1": "Crop insurance to small and marginal farmers.",
        "Option2": "Minimum Support Price (MSP) for all crops.",
        "Option3": "Financial benefit to all landholding farmer families.",
        "Option4": "Subsidized seeds and fertilizers.",
        "Correct Option": "Financial benefit to all landholding farmer families."
    },
    {
        "Question": "The 'Global Innovation Index' is published by which international organization?",
        "Option1": "World Bank",
        "Option2": "World Economic Forum (WEF)",
        "Option3": "World Intellectual Property Organization (WIPO)",
        "Option4": "UNIDO",
        "Correct Option": "World Intellectual Property Organization (WIPO)"
    },
    {
        "Question": "The 'Mission Vatsalya' scheme of the Government of India is aimed at achieving which of the following?",
        "Option1": "Women's empowerment and safety.",
        "Option2": "Child protection services and welfare.",
        "Option3": "Universal health coverage.",
        "Option4": "Promoting skill development for youth.",
        "Correct Option": "Child protection services and welfare."
    },
    {
        "Question": "The 'Kuno National Park', famous for the reintroduction of Cheetahs, is located in which state?",
        "Option1": "Rajasthan",
        "Option2": "Gujarat",
        "Option3": "Madhya Pradesh",
        "Option4": "Maharashtra",
        "Correct Option": "Madhya Pradesh"
    },
    {
        "Question": "Which of the following bodies regulates the trading of derivatives in the Indian commodity market?",
        "Option1": "Reserve Bank of India (RBI)",
        "Option2": "Securities and Exchange Board of India (SEBI)",
        "Option3": "Forward Markets Commission (FMC) (merged with SEBI)",
        "Option4": "NITI Aayog",
        "Correct Option": "Securities and Exchange Board of India (SEBI)"
    },
    {
        "Question": "The 'Intergovernmental Science-Policy Platform on Biodiversity and Ecosystem Services (IPBES)' is often referred to as the $\text{IPCC}$ for:",
        "Option1": "Oceans",
        "Option2": "Biodiversity",
        "Option3": "Desertification",
        "Option4": "Forestry",
        "Correct Option": "Biodiversity"
    },
    {
        "Question": "The 'Digital Personal Data Protection Act, 2023' primarily aims to regulate:",
        "Option1": "The use of personal data by foreign companies.",
        "Option2": "The processing of digital personal data by entities.",
        "Option3": "Cross-border data flow for government agencies.",
        "Option4": "The sharing of Aadhar data with private entities.",
        "Correct Option": "The processing of digital personal data by entities."
    },
    {
        "Question": "Which river system is associated with the 'Ken-Betwa Link Project'?",
        "Option1": "Godavari-Krishna",
        "Option2": "Ganga-Yamuna",
        "Option3": "Peninsular rivers (Narmada-Tapi)",
        "Option4": "Yamuna and its tributaries",
        "Correct Option": "Yamuna and its tributaries"
    },
    {
        "Question": "The 'India Energy Week (IEW)' is an annual flagship event of which Ministry?",
        "Option1": "Ministry of Power",
        "Option2": "Ministry of Coal",
        "Option3": "Ministry of New and Renewable Energy",
        "Option4": "Ministry of Petroleum and Natural Gas",
        "Correct Option": "Ministry of Petroleum and Natural Gas"
    },
    {
        "Question": "Which of the following is NOT one of the 8 Core Industries of the Index of Industrial Production (IIP) in India?",
        "Option1": "Cement",
        "Option2": "Textiles",
        "Option3": "Natural Gas",
        "Option4": "Electricity",
        "Correct Option": "Textiles"
    },
    {
        "Question": "The 'Kharif Marketing Season (KMS)' in India typically refers to the procurement period for which major crop?",
        "Option1": "Wheat",
        "Option2": "Sugarcane",
        "Option3": "Rice",
        "Option4": "Mustard",
        "Correct Option": "Rice"
    },
    {
        "Question": "The 'Global Water Partnership (GWP)', an international network, focuses on promoting which concept?",
        "Option1": "Water privatization",
        "Option2": "Integrated Water Resources Management (IWRM)",
        "Option3": "Desalination technology",
        "Option4": "Groundwater exploration",
        "Correct Option": "Integrated Water Resources Management (IWRM)"
    },
    {
        "Question": "The 'LiDAR' (Light Detection and Ranging) survey technique, often used in infrastructure projects, is primarily useful for:",
        "Option1": "Detecting underground water sources.",
        "Option2": "Creating high-resolution 3D maps of the terrain.",
        "Option3": "Measuring air pollution levels.",
        "Option4": "Monitoring seismic activity.",
        "Correct Option": "Creating high-resolution 3D maps of the terrain."
    },
    {
        "Question": "Which country recently achieved the feat of cloning a wild Arctic wolf, a landmark in conservation science?",
        "Option1": "USA",
        "Option2": "Russia",
        "Option3": "China",
        "Option4": "Canada",
        "Correct Option": "China"
    },
    {
        "Question": "The 'Project Elephant', launched in 1992, is managed by which Union Ministry?",
        "Option1": "Ministry of Agriculture and Farmers Welfare",
        "Option2": "Ministry of Environment, Forest and Climate Change",
        "Option3": "Ministry of Tribal Affairs",
        "Option4": "Ministry of Home Affairs",
        "Correct Option": "Ministry of Environment, Forest and Climate Change"
    },
    {
        "Question": "The 'G-20 Sherpa' for India, who plays a crucial role in negotiations and preparing for the summit, is currently:",
        "Option1": "The Minister of External Affairs",
        "Option2": "The Finance Minister",
        "Option3": "A retired high-ranking bureaucrat appointed by the PM",
        "Option4": "The Cabinet Secretary",
        "Correct Option": "A retired high-ranking bureaucrat appointed by the PM"
    },
    {
        "Question": "The 'Financial Stability and Development Council (FSDC)' is chaired by the:",
        "Option1": "Governor of RBI",
        "Option2": "Prime Minister",
        "Option3": "Union Finance Minister",
        "Option4": "NITI Aayog Vice-Chairman",
        "Correct Option": "Union Finance Minister"
    },
    {
        "Question": "Which of the following is the world's largest coal-exporting country?",
        "Option1": "Australia",
        "Option2": "Indonesia",
        "Option3": "Russia",
        "Option4": "South Africa",
        "Correct Option": "Australia"
    },
    {
        "Question": "The 'International Solar Alliance (ISA)', co-founded by India, has its headquarters in:",
        "Option1": "New Delhi",
        "Option2": "Bengaluru",
        "Option3": "Gurugram",
        "Option4": "Geneva",
        "Correct Option": "Gurugram"
    },
    {
        "Question": "The 'PM-eVIDYA' program is a Government of India initiative for:",
        "Option1": "Providing online education using digital infrastructure.",
        "Option2": "Financial assistance for higher education.",
        "Option3": "Skill development for women.",
        "Option4": "Digital literacy in rural areas.",
        "Correct Option": "Providing online education using digital infrastructure."
    },
    {
        "Question": "Which organization recently released the 'World Social Report' focusing on global inequalities?",
        "Option1": "International Labour Organization (ILO)",
        "Option2": "World Bank",
        "Option3": "United Nations (UN) Department of Economic and Social Affairs (DESA)",
        "Option4": "UNICEF",
        "Correct Option": "United Nations (UN) Department of Economic and Social Affairs (DESA)"
    },
    {
        "Question": "The 'Atal Tunnel', the world's longest highway tunnel above 10,000 feet, connects which two valleys in Himachal Pradesh?",
        "Option1": "Kullu and Chamba",
        "Option2": "Parvati and Malana",
        "Option3": "Kullu and Lahaul-Spiti",
        "Option4": "Kinnaur and Spiti",
        "Correct Option": "Kullu and Lahaul-Spiti"
    },
    {
        "Question": "The 'Global Terrorism Index' is published by:",
        "Option1": "United Nations Office on Drugs and Crime (UNODC)",
        "Option2": "Institute for Economics & Peace (IEP)",
        "Option3": "Amnesty International",
        "Option4": "Interpol",
        "Correct Option": "Institute for Economics & Peace (IEP)"
    },
    {
        "Question": "The term 'Grey Money' is often used to describe:",
        "Option1": "Illegal funds generated through drug trafficking.",
        "Option2": "Income generated through legal means but not reported for tax purposes.",
        "Option3": "Funds used in political campaigning without proper declaration.",
        "Option4": "Money involved in cross-border trade without proper documentation.",
        "Correct Option": "Income generated through legal means but not reported for tax purposes."
    },
    {
        "Question": "India's first 'Forest University' is proposed to be established in which state?",
        "Option1": "Uttarakhand",
        "Option2": "Himachal Pradesh",
        "Option3": "Telangana",
        "Option4": "Assam",
        "Correct Option": "Telangana"
    },
    {
        "Question": "The $\text{G-7}$ group of nations includes Canada, France, Germany, Italy, Japan, $\text{UK}$, $\text{USA}$, and:",
        "Option1": "Russia",
        "Option2": "China",
        "Option3": "European Union (EU) as a non-enumerated member",
        "Option4": "India",
        "Correct Option": "European Union (EU) as a non-enumerated member"
    },
    {
        "Question": "The 'World Heritage Convention' is administered by:",
        "Option1": "UNEP",
        "Option2": "UNDP",
        "Option3": "UNESCO",
        "Option4": "IUCN",
        "Correct Option": "UNESCO"
    },
    {
        "Question": "The 'Vigyan Sarvatra Pujyate' program, a national movement, was launched to celebrate:",
        "Option1": "India's independence.",
        "Option2": "The fusion of science and culture.",
        "Option3": "India's achievements in Science and Technology.",
        "Option4": "The birth centenary of a famous scientist.",
        "Correct Option": "India's achievements in Science and Technology."
    },
    {
        "Question": "Which of the following is the newest 'Tiger Reserve' declared in India?",
        "Option1": "Ramgarh Vishdhari Tiger Reserve (Rajasthan)",
        "Option2": "Guru Ghasidas National Park and Tamor Pingla Wildlife Sanctuary (Chhattisgarh)",
        "Option3": "Dholpur-Karauli Tiger Reserve (Rajasthan)",
        "Option4": "Sathyamangalam Tiger Reserve (Tamil Nadu)",
        "Correct Option": "Dholpur-Karauli Tiger Reserve (Rajasthan)"
    },
    {
        "Question": "The 'PM-KUSUM' scheme is primarily aimed at boosting the use of which energy source in agriculture?",
        "Option1": "Wind energy",
        "Option2": "Biomass energy",
        "Option3": "Solar energy",
        "Option4": "Geothermal energy",
        "Correct Option": "Solar energy"
    },
    {
        "Question": "The 'Unified Portal for Credit-Linked Government Schemes (Jan Samarth Portal)' is primarily aimed at providing:",
        "Option1": "Access to government social security schemes.",
        "Option2": "A common platform for all government subsidy schemes.",
        "Option3": "A single platform for all credit-linked government schemes.",
        "Option4": "Online application for $\text{Aadhar}$ and $\text{PAN}$ cards.",
        "Correct Option": "A single platform for all credit-linked government schemes."
    },
    {
        "Question": "The 'International Criminal Court (ICC)', often in news, is headquartered at:",
        "Option1": "New York",
        "Option2": "Geneva",
        "Option3": "The Hague",
        "Option4": "Brussels",
        "Correct Option": "The Hague"
    },
    {
        "Question": "Which of the following has been recently designated as India's first $\text{Geological}$ $\text{Heritage}$ $\text{Site}$?",
        "Option1": "Lonar Lake, Maharashtra",
        "Option2": "St. Mary's Island, Karnataka",
        "Option3": "Visakhapatnam Coast, Andhra Pradesh",
        "Option4": "A geological site is not a designated heritage site.",
        "Correct Option": "A geological site is not a designated heritage site."
    },
    {
        "Question": "The 'PM MITRA' scheme, a major textile industry initiative, stands for:",
        "Option1": "Mega Integrated Textile Regions and Apparel",
        "Option2": "Prime Minister's Textile Research & Advancement",
        "Option3": "Modern Industrial Training and Research Authority",
        "Option4": "Micro Infrastructure for Textile Revenue and Apparel",
        "Correct Option": "Mega Integrated Textile Regions and Apparel"
    }
]

# Create a DataFrame from the list of dictionaries
df = pd.DataFrame(current_affairs_data)

# Save the DataFrame to a CSV file
csv_file_path = "UPSC_Current_Affairs_MCQ_Dataset.csv"
df.to_csv(csv_file_path, index=False)

print(f"Successfully generated the CSV file: {csv_file_path}")
print("\nFirst 5 rows of the generated dataset:")
print(df.head().to_string(index=False))
# Out:
# Successfully generated the CSV file: UPSC_Current_Affairs_MCQ_Dataset.csv
#
# First 5 rows of the generated dataset:
#                                                                                                                                                                                                                                                                                                                                                    Question                                       Option1                                      Option2                                                                          Option3                                                Option4               Correct Option
# ...
