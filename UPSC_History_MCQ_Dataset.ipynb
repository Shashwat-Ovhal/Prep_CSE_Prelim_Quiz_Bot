# %%
import pandas as pd

# Data for the 100 questions
# This is a combination of the first 20 and the next 80 questions provided earlier.

mcq_data = [
    # --- Ancient History (Q1-Q40) ---
    {"Question": "With reference to the Indus Valley Civilization, consider the following statements:\n1. The people built their houses of baked bricks.\n2. They were the first to develop a script (pictographic).\n3. They did not know the use of iron.\nWhich of the statements given above are correct?", "Option1": "1 and 2 only", "Option2": "2 and 3 only", "Option3": "1 and 3 only", "Option4": "1, 2 and 3", "CorrectOption": "1, 2 and 3"},
    {"Question": "Which one of the following is known as the 'Book of Chants' and consists of a collection of melodies and hymns meant to be sung during religious rituals?", "Option1": "Rigveda", "Option2": "Yajurveda", "Option3": "Samaveda", "Option4": "Atharvaveda", "CorrectOption": "Samaveda"},
    {"Question": "Which of the following statements about Mahavira and Jainism is NOT correct?", "Option1": "He was the 24th Tirthankara of the Jain tradition.", "Option2": "He believed in the doctrine of 'Anuvrata' (small vows) for householders.", "Option3": "He advocated a life of extreme austerity and non-injury (Ahimsa).", "Option4": "His early teachings were written in Sanskrit, which was understood by the masses.", "CorrectOption": "His early teachings were written in Sanskrit, which was understood by the masses."},
    {"Question": "Who among the following rulers of the Gupta Dynasty was called the 'Napoleon of India' for his extensive military campaigns and conquests?", "Option1": "Chandragupta I", "Option2": "Samudragupta", "Option3": "Chandragupta II", "Option4": "Skandagupta", "CorrectOption": "Samudragupta"},
    {"Question": "The famous Chinese pilgrim Fa-Hien visited India during the reign of:", "Option1": "Harsha", "Option2": "Chandragupta I", "Option3": "Chandragupta II", "Option4": "Ashoka", "CorrectOption": "Chandragupta II"},
    {"Question": "Which of the following Harappan sites is known for its evidence of a dockyard?", "Option1": "Harappa", "Option2": "Mohenjo-Daro", "Option3": "Lothal", "Option4": "Kalibangan", "CorrectOption": "Lothal"},
    {"Question": "The earliest evidence of settled agriculture in the Indian subcontinent comes from:", "Option1": "Amri", "Option2": "Mehrgarh", "Option3": "Koldihwa", "Option4": "Burzahom", "CorrectOption": "Mehrgarh"},
    {"Question": "The two major components of the later Vedic economy were:", "Option1": "Trade and Commerce", "Option2": "Agriculture and Cattle rearing", "Option3": "Hunting and Gathering", "Option4": "Mining and Metallurgy", "CorrectOption": "Agriculture and Cattle rearing"},
    {"Question": "The famous 'Ten Kings Battle' (Dasarajna) mentioned in the Rigveda was fought on the banks of which river?", "Option1": "Saraswati", "Option2": "Sindhu", "Option3": "Parushni (Ravi)", "Option4": "Sutudri (Sutlej)", "CorrectOption": "Parushni (Ravi)"},
    {"Question": "The term 'Upanishad' literally means:", "Option1": "Recitation of verses", "Option2": "Sitting near", "Option3": "Great sacrifice", "Option4": "Sacred knowledge", "CorrectOption": "Sitting near"},
    {"Question": "Which Buddhist council was held in Kashmir under the patronage of Kanishka?", "Option1": "First", "Option2": "Second", "Option3": "Third", "Option4": "Fourth", "CorrectOption": "Fourth"},
    {"Question": "The practice of 'Stupa' building in the Buddhist tradition is primarily intended to be a:", "Option1": "Monastery for monks", "Option2": "Repository of relics", "Option3": "Place for public sermons", "Option4": "Residential place for the Buddha", "CorrectOption": "Repository of relics"},
    {"Question": "The rock-cut caves at Ajanta predominantly depict stories from the:", "Option1": "Ramayana", "Option2": "Mahabharata", "Option3": "Jatakas", "Option4": "Panchatantra", "CorrectOption": "Jatakas"},
    {"Question": "Which Mauryan ruler embraced Buddhism and propagated it widely through rock and pillar edicts?", "Option1": "Chandragupta Maurya", "Option2": "Bindusara", "Option3": "Ashoka", "Option4": "Dasaratha", "CorrectOption": "Ashoka"},
    {"Question": "The capital of the Satavahanas was located at:", "Option1": "Madurai", "Option2": "Kanchi", "Option3": "Paithan (Pratishthana)", "Option4": "Pataliputra", "CorrectOption": "Paithan (Pratishthana)"},
    {"Question": "Charaka and Sushruta were famous practitioners in the field of:", "Option1": "Mathematics", "Option2": "Astronomy", "Option3": "Medicine", "Option4": "Literature", "CorrectOption": "Medicine"},
    {"Question": "The subject matter of the text 'Pancha-siddhantika' by Varahamihira is:", "Option1": "Philosophy", "Option2": "Astronomy", "Option3": "Grammar", "Option4": "Poetry", "CorrectOption": "Astronomy"},
    {"Question": "The term 'Nagara, Dravida, and Vesara' are related to:", "Option1": "Castes and Varnas", "Option2": "Styles of Temple Architecture", "Option3": "Administrative Divisions", "Option4": "Land Revenue Systems", "CorrectOption": "Styles of Temple Architecture"},
    {"Question": "The famous temple of Hoysaleswara is situated at:", "Option1": "Hampi", "Option2": "Belur", "Option3": "Halebid", "Option4": "Somanathpur", "CorrectOption": "Halebid"},
    {"Question": "The ancient port city of Arikamedu near Pondicherry provides evidence of trade relations with:", "Option1": "China", "Option2": "Southeast Asia", "Option3": "Roman Empire", "Option4": "Greece", "CorrectOption": "Roman Empire"},
    {"Question": "The Tamil epic 'Silappatikaram' was composed by:", "Option1": "Tiruvalluvar", "Option2": "Ilango Adigal", "Option3": "Sattanar", "Option4": "Nakkirar", "CorrectOption": "Ilango Adigal"},
    {"Question": "Which ruler issued the largest number of copper coins?", "Option1": "Mauryas", "Option2": "Guptas", "Option3": "Kushanas", "Option4": "Cholas", "CorrectOption": "Kushanas"},
    {"Question": "The concept of 'Tirukkural' (Sacred Couplets) is associated with which Tamil poet?", "Option1": "Kambar", "Option2": "Sekkizhar", "Option3": "Thiruvalluvar", "Option4": "Avvaiyar", "CorrectOption": "Thiruvalluvar"},
    {"Question": "Which ruler repaired the Sudarshan Lake for the second time, whose repairs were also mentioned in the Junagarh Rock Inscription?", "Option1": "Ashoka", "Option2": "Rudradaman", "Option3": "Skandagupta", "Option4": "Kanishka", "CorrectOption": "Skandagupta"},
    {"Question": "The rock inscription which provides information about the naval strength of the Chalukya ruler Pulakeshin II is the:", "Option1": "Aihole Inscription", "Option2": "Allahabad Pillar Inscription", "Option3": "Hathigumpha Inscription", "Option4": "Sanchi Stupa Inscription", "CorrectOption": "Aihole Inscription"},

    # --- Medieval History (Q41-Q60) ---
    {"Question": "The term 'Iqtadar' (later 'Iqta') in the Delhi Sultanate referred to:", "Option1": "A religious tax levied on non-Muslims.", "Option2": "A land grant assigned to military officers/nobles in lieu of salary.", "Option3": "The head of the religious department.", "Option4": "The royal cavalry division commander.", "CorrectOption": "A land grant assigned to military officers/nobles in lieu of salary."},
    {"Question": "Which Sultan of Delhi established the city of Agra in 1504 and made it his capital?", "Option1": "Iltutmish", "Option2": "Balban", "Option3": "Sikandar Lodi", "Option4": "Firoz Shah Tughlaq", "CorrectOption": "Sikandar Lodi"},
    {"Question": "The Vijayanagara ruler who constructed a large dam across the Tungabhadra River and a canal-cum-aqueduct for the capital city was:", "Option1": "Devaraya I", "Option2": "Krishnadeva Raya", "Option3": "Achyuta Deva Raya", "Option4": "Sadasiva Raya", "CorrectOption": "Devaraya I"},
    {"Question": "Who among the following was the court historian of Akbar and authored the 'Ain-i-Akbari' and 'Akbar Nama'?", "Option1": "Faizi", "Option2": "Birbal", "Option3": "Abul Fazl", "Option4": "Todar Mal", "CorrectOption": "Abul Fazl"},
    {"Question": "With reference to medieval India, which one of the following terms correctly defines 'Chauth' and 'Sardeshmukhi'?", "Option1": "Two types of land taxes under the Mughals.", "Option2": "Taxes collected by the Marathas.", "Option3": "Titles adopted by rulers in the Deccan region.", "Option4": "Administrative departments under the Bahmani kingdom.", "CorrectOption": "Taxes collected by the Marathas."},
    {"Question": "The Persian festival of 'Nauroz' was introduced in India by which Sultan of Delhi?", "Option1": "Balban", "Option2": "Iltutmish", "Option3": "Alauddin Khilji", "Option4": "Firoz Shah Tughlaq", "CorrectOption": "Balban"},
    {"Question": "The traveler Ibn Battuta visited India during the reign of:", "Option1": "Alauddin Khilji", "Option2": "Muhammad bin Tughlaq", "Option3": "Firoz Shah Tughlaq", "Option4": "Ibrahim Lodi", "CorrectOption": "Muhammad bin Tughlaq"},
    {"Question": "The Delhi Sultan who shifted his capital from Delhi to Daulatabad was:", "Option1": "Qutb-ud-din Aibak", "Option2": "Iltutmish", "Option3": "Alauddin Khilji", "Option4": "Muhammad bin Tughlaq", "CorrectOption": "Muhammad bin Tughlaq"},
    {"Question": "The Sufi saint who was referred to as 'Mahbub-i-Ilahi' (Beloved of God) was:", "Option1": "Muinuddin Chishti", "Option2": "Nizamuddin Auliya", "Option3": "Baba Farid", "Option4": "Nasiruddin Chirag-i-Dehli", "CorrectOption": "Nizamuddin Auliya"},
    {"Question": "The Ashtadiggajas were a group of eight great scholars in the court of:", "Option1": "Harihara I", "Option2": "Devaraya II", "Option3": "Krishnadeva Raya", "Option4": "Vira Narasimha Raya", "CorrectOption": "Krishnadeva Raya"},
    {"Question": "The 'Battle of Talikota' (1565), which led to the decline of the Vijayanagara Empire, was fought against:", "Option1": "The Portuguese", "Option2": "The alliance of Deccan Sultanates", "Option3": "The Bahmani Kingdom", "Option4": "The Marathas", "CorrectOption": "The alliance of Deccan Sultanates"},
    {"Question": "The 'Zabti' system, a land revenue system perfected during Akbar's reign, was primarily associated with:", "Option1": "Abul Fazl", "Option2": "Raja Todar Mal", "Option3": "Birbal", "Option4": "Tansen", "CorrectOption": "Raja Todar Mal"},
    {"Question": "The Mughal Queen whose name was inscribed on the coins and who had extensive political influence was:", "Option1": "Hamida Banu Begum", "Option2": "Nur Jahan", "Option3": "Mumtaz Mahal", "Option4": "Jahanara Begum", "CorrectOption": "Nur Jahan"},
    {"Question": "The construction of the Red Fort (Lal Qila) in Delhi was completed during the reign of:", "Option1": "Akbar", "Option2": "Jahangir", "Option3": "Shah Jahan", "Option4": "Aurangzeb", "CorrectOption": "Shah Jahan"},
    {"Question": "The main feature of the 'Mansabdari System' introduced by Akbar was the dual rank of:", "Option1": "Diwan and Bakshi", "Option2": "Subedar and Faujdar", "Option3": "Zat and Sawar", "Option4": "Quazi and Sadr", "CorrectOption": "Zat and Sawar"},
    {"Question": "The Sikh Guru who was executed by the Mughal Emperor Aurangzeb was:", "Option1": "Guru Arjan Dev", "Option2": "Guru Tegh Bahadur", "Option3": "Guru Gobind Singh", "Option4": "Guru Ram Das", "CorrectOption": "Guru Tegh Bahadur"},
    {"Question": "Which Maratha ruler was given the title 'Chhatrapati'?", "Option1": "Shivaji", "Option2": "Sambhaji", "Option3": "Rajaram", "Option4": "Shahu", "CorrectOption": "Shivaji"},
    {"Question": "The term 'Peshwa' in the Maratha administration referred to the:", "Option1": "Commander-in-Chief", "Option2": "Prime Minister", "Option3": "Foreign Minister", "Option4": "Head of Intelligence", "CorrectOption": "Prime Minister"},
    {"Question": "The First Battle of Panipat in 1526 was fought between:", "Option1": "Babur and Rana Sanga", "Option2": "Humayun and Sher Shah Suri", "Option3": "Babur and Ibrahim Lodi", "Option4": "Akbar and Hemu", "CorrectOption": "Babur and Ibrahim Lodi"},
    {"Question": "Which monument is described as the 'dream in marble'?", "Option1": "Red Fort", "Option2": "Jama Masjid", "Option3": "Taj Mahal", "Option4": "Fatehpur Sikri", "CorrectOption": "Taj Mahal"},
    {"Question": "The author of 'Tarikh-i-Firoz Shahi', providing details of the Tughlaq dynasty, was:", "Option1": "Amir Khusrau", "Option2": "Ziauddin Barani", "Option3": "Minhaj-i-Siraj", "Option4": "Abdul Hamid Lahori", "CorrectOption": "Ziauddin Barani"},
    {"Question": "The famous Persian poet who came to India with Mahmud of Ghazni was:", "Option1": "Firdausi", "Option2": "Al-Beruni", "Option3": "Rumi", "Option4": "Sadi", "CorrectOption": "Al-Beruni"},
    {"Question": "The most important architectural element introduced by the Turkish rulers was the:", "Option1": "Dome", "Option2": "Minar", "Option3": "Arch and Dome", "Option4": "Calligraphy", "CorrectOption": "Arch and Dome"},
    {"Question": "Which Bahmani Sultan shifted the capital from Gulbarga to Bidar?", "Option1": "Alauddin Bahman Shah", "Option2": "Muhammad Shah I", "Option3": "Ahmad Shah Wali", "Option4": "Humayun Shah", "CorrectOption": "Ahmad Shah Wali"},
    {"Question": "The 'Dharat' and 'Gali' were local terms related to:", "Option1": "Land measurement", "Option2": "Village artisans", "Option3": "Paper currency of the Mughals", "Option4": "Taxation on houses and shops", "CorrectOption": "Taxation on houses and shops"},

    # --- Modern History (Q61-Q100) ---
    {"Question": "By which one of the following Acts was the Governor-General of Bengal designated as the Governor-General of India?", "Option1": "The Regulating Act, 1773", "Option2": "The Pitt’s India Act, 1784", "Option3": "The Charter Act of 1813", "Option4": "The Charter Act of 1833", "CorrectOption": "The Charter Act of 1833"},
    {"Question": "Raja Ram Mohan Roy founded the Brahmo Sabha in 1828, which later came to be known as Brahmo Samaj. Which of the following was its chief aim?", "Option1": "Promoting English education among women.", "Option2": "Worship of the eternal God and opposing idol worship.", "Option3": "Advocating for the upliftment of the depressed classes.", "Option4": "Fighting against the practice of child marriage.", "CorrectOption": "Worship of the eternal God and opposing idol worship."},
    {"Question": "Who was the Viceroy of India when the Jallianwala Bagh massacre took place in 1919?", "Option1": "Lord Curzon", "Option2": "Lord Hardinge", "Option3": "Lord Chelmsford", "Option4": "Lord Reading", "CorrectOption": "Lord Chelmsford"},
    {"Question": "The 'Tebhaga' Movement of 1946-47 in Bengal was essentially a:", "Option1": "Peasant movement for reduction of rent.", "Option2": "Movement of plantation workers.", "Option3": "Movement for the right to form associations.", "Option4": "Tribal uprising against forest laws.", "CorrectOption": "Peasant movement for reduction of rent."},
    {"Question": "The Gandhi-Irwin Pact was associated with which of the following movements?", "Option1": "Khilafat Movement", "Option2": "Non-Cooperation Movement", "Option3": "Civil Disobedience Movement", "Option4": "Quit India Movement", "CorrectOption": "Civil Disobedience Movement"},
    {"Question": "Who was the only Governor-General of India to be impeached by the British Parliament?", "Option1": "Lord Cornwallis", "Option2": "Warren Hastings", "Option3": "Lord Wellesley", "Option4": "Lord William Bentinck", "CorrectOption": "Warren Hastings"},
    {"Question": "Consider the following pairs:\n1. Hunter Commission: Elementary Education\n2. Sadler Commission: University Education\n3. Wood's Despatch: Foundation of Education in India\nWhich of the pairs given above is/are correctly matched?", "Option1": "1 only", "Option2": "2 and 3 only", "Option3": "1 and 3 only", "Option4": "1, 2 and 3", "CorrectOption": "1, 2 and 3"},
    {"Question": "Who among the following founded the Indian Home Rule League in September 1916?", "Option1": "Bal Gangadhar Tilak", "Option2": "Annie Besant", "Option3": "Mahatma Gandhi", "Option4": "Lala Lajpat Rai", "CorrectOption": "Annie Besant"},
    {"Question": "The Cripps Mission was sent to India in 1942 with the primary purpose of:", "Option1": "Transferring power to a fully representative Indian government.", "Option2": "Securing Indian cooperation in the Second World War.", "Option3": "Negotiating the partition of India.", "Option4": "Setting up a provisional government.", "CorrectOption": "Securing Indian cooperation in the Second World War."},
    {"Question": "Who succeeded Lord Mountbatten as the first and only Indian Governor-General of independent India?", "Option1": "Jawaharlal Nehru", "Option2": "Dr. Rajendra Prasad", "Option3": "C. Rajagopalachari", "Option4": "Sardar Vallabhbhai Patel", "CorrectOption": "C. Rajagopalachari"},
    {"Question": "The Treaty of Seringapatam (1792) was signed between Tipu Sultan and:", "Option1": "Lord Dalhousie", "Option2": "Lord Wellesley", "Option3": "Lord Cornwallis", "Option4": "Lord Hastings", "CorrectOption": "Lord Cornwallis"},
    {"Question": "The Subsidiary Alliance System in India was introduced by:", "Option1": "Robert Clive", "Option2": "Lord Wellesley", "Option3": "Lord Dalhousie", "Option4": "Lord Canning", "CorrectOption": "Lord Wellesley"},
    {"Question": "The system of Permanent Settlement was introduced in Bengal by:", "Option1": "Warren Hastings", "Option2": "Lord Cornwallis", "Option3": "Lord Minto", "Option4": "Lord William Bentinck", "CorrectOption": "Lord Cornwallis"},
    {"Question": "Which Governor-General abolished Sati in 1829?", "Option1": "Lord Hardinge", "Option2": "Lord Auckland", "Option3": "Lord Dalhousie", "Option4": "Lord William Bentinck", "CorrectOption": "Lord William Bentinck"},
    {"Question": "The 'Doctrine of Lapse' was primarily associated with:", "Option1": "Lord Curzon", "Option2": "Lord Dalhousie", "Option3": "Lord Canning", "Option4": "Lord Ripon", "CorrectOption": "Lord Dalhousie"},
    {"Question": "Who was the author of the book 'Poverty and Un-British Rule in India'?", "Option1": "R.C. Dutt", "Option2": "B.G. Tilak", "Option3": "Dadabhai Naoroji", "Option4": "G.K. Gokhale", "CorrectOption": "Dadabhai Naoroji"},
    {"Question": "The first session of the Indian National Congress (INC) was held in:", "Option1": "Calcutta", "Option2": "Bombay", "Option3": "Madras", "Option4": "Poona", "CorrectOption": "Bombay"},
    {"Question": "The INC split into Moderates and Extremists at the Surat Session in which year?", "Option1": "1905", "Option2": "1906", "Option3": "1907", "Option4": "1909", "CorrectOption": "1907"},
    {"Question": "The Partition of Bengal was annulled in which year?", "Option1": "1909", "Option2": "1911", "Option3": "1919", "Option4": "1921", "CorrectOption": "1911"},
    {"Question": "The Ghadar Party was formed in 1913 primarily by:", "Option1": "Indians in Germany", "Option2": "Indians in the USA and Canada", "Option3": "Revolutionaries in Bengal", "Option4": "Indians in South Africa", "CorrectOption": "Indians in the USA and Canada"},
    {"Question": "The 'Swadeshi Movement' was a reaction to the:", "Option1": "Vernacular Press Act", "Option2": "Rowlatt Act", "Option3": "Partition of Bengal", "Option4": "Dandi March", "CorrectOption": "Partition of Bengal"},
    {"Question": "The Champaran Satyagraha (1917) was concerned with:", "Option1": "Salt tax", "Option2": "Indigo planters", "Option3": "Land revenue", "Option4": "Mill workers", "CorrectOption": "Indigo planters"},
    {"Question": "Who was the founder of the Ramakrishna Mission?", "Option1": "Raja Ram Mohan Roy", "Option2": "Swami Dayananda Saraswati", "Option3": "Swami Vivekananda", "Option4": "Ishwar Chandra Vidyasagar", "CorrectOption": "Swami Vivekananda"},
    {"Question": "The Rowlatt Act (1919) was called the 'Black Act' because it:", "Option1": "Increased land tax", "Option2": "Banned Indian newspapers", "Option3": "Allowed detention without trial", "Option4": "Forced workers into slavery", "CorrectOption": "Allowed detention without trial"},
    {"Question": "The Non-Cooperation Movement was suspended after the violent incident at:", "Option1": "Jallianwala Bagh", "Option2": "Chauri Chaura", "Option3": "Kanpur", "Option4": "Bardoli", "CorrectOption": "Chauri Chaura"},
    {"Question": "The main purpose of the Simon Commission (1927) was to:", "Option1": "Review the working of the Montagu-Chelmsford Reforms (1919)", "Option2": "Investigate the Jallianwala Bagh incident", "Option3": "Negotiate with the Muslim League", "Option4": "Discuss the future role of Princely States", "CorrectOption": "Review the working of the Montagu-Chelmsford Reforms (1919)"},
    {"Question": "The 'Poona Pact' (1932) was an agreement between Mahatma Gandhi and:", "Option1": "Lord Irwin", "Option2": "B. R. Ambedkar", "Option3": "Muhammad Ali Jinnah", "Option4": "Sardar Patel", "CorrectOption": "B. R. Ambedkar"},
    {"Question": "The demand for 'Purna Swaraj' (Complete Independence) was made at the INC session held at:", "Option1": "Calcutta (1928)", "Option2": "Lahore (1929)", "Option3": "Karachi (1931)", "Option4": "Lucknow (1936)", "CorrectOption": "Lahore (1929)"},
    {"Question": "The Cripps Mission was rejected by the INC primarily because it offered:", "Option1": "Separate electorates", "Option2": "Only Dominion Status after the war", "Option3": "Full independence immediately", "Option4": "Partition of India", "CorrectOption": "Only Dominion Status after the war"},
    {"Question": "The Quit India Resolution was passed in the year:", "Option1": "1940", "Option2": "1941", "Option3": "1942", "Option4": "1943", "CorrectOption": "1942"},
    {"Question": "Who was the first President of the Indian National Congress?", "Option1": "A.O. Hume", "Option2": "Dadabhai Naoroji", "Option3": "W. C. Bonnerjee", "Option4": "Badruddin Tyabji", "CorrectOption": "W. C. Bonnerjee"},
    {"Question": "The Aligarh Movement was founded by:", "Option1": "Muhammad Ali Jinnah", "Option2": "Sir Syed Ahmad Khan", "Option3": "Abul Kalam Azad", "Option4": "Shibli Nomani", "CorrectOption": "Sir Syed Ahmad Khan"},
    {"Question": "The Vernacular Press Act (1878) was repealed by:", "Option1": "Lord Lytton", "Option2": "Lord Ripon", "Option3": "Lord Dufferin", "Option4": "Lord Curzon", "CorrectOption": "Lord Ripon"},
    {"Question": "The Ilbert Bill Controversy in 1883 primarily dealt with:", "Option1": "Reducing Indian army strength", "Option2": "Allowing Indian judges to try Europeans", "Option3": "Land reforms in Bengal", "Option4": "Abolition of Press censorship", "CorrectOption": "Allowing Indian judges to try Europeans"},
    {"Question": "Who started the newspaper 'Kesari' in Marathi?", "Option1": "G.K. Gokhale", "Option2": "B.G. Tilak", "Option3": "M.G. Ranade", "Option4": "Lala Lajpat Rai", "CorrectOption": "B.G. Tilak"},
    {"Question": "The 'August Offer' of 1940 was proposed by:", "Option1": "Lord Linlithgow", "Option2": "Lord Wavell", "Option3": "Lord Mountbatten", "Option4": "Lord Reading", "CorrectOption": "Lord Linlithgow"},
    {"Question": "The Indian Independence Act was passed by the British Parliament in:", "Option1": "July 1947", "Option2": "August 1947", "Option3": "June 1948", "Option4": "January 1950", "CorrectOption": "July 1947"},
    {"Question": "Who gave the slogan 'Do or Die' (Karo ya Maro) during the Quit India Movement?", "Option1": "Subhas Chandra Bose", "Option2": "Mahatma Gandhi", "Option3": "Jawaharlal Nehru", "Option4": "Bhagat Singh", "CorrectOption": "Mahatma Gandhi"},
    {"Question": "The first session of the Constituent Assembly of India was held in:", "Option1": "1946", "Option2": "1947", "Option3": "1948", "Option4": "1950", "CorrectOption": "1946"},
    {"Question": "The Cabinet Mission Plan of 1946 proposed which of the following?", "Option1": "Immediate partition of India", "Option2": "Formation of a Constituent Assembly", "Option3": "Full independence immediately", "Option4": "Complete rejection of Muslim League demands", "CorrectOption": "Formation of a Constituent Assembly"},
    {"Question": "Who was the founder of the Aurobindo Ashram in Puducherry?", "Option1": "Bal Gangadhar Tilak", "Option2": "Aurobindo Ghosh", "Option3": "Swami Dayananda", "Option4": "Annie Besant", "CorrectOption": "Aurobindo Ghosh"},
    {"Question": "The Wagon Tragedy (1921) is associated with which rebellion?", "Option1": "Santhal Rebellion", "Option2": "Moplah Rebellion", "Option3": "Indigo Revolt", "Option4": "Ramosi Rebellion", "CorrectOption": "Moplah Rebellion"},
    {"Question": "The First Round Table Conference in London was held in:", "Option1": "1930", "Option2": "1931", "Option3": "1932", "Option4": "1935", "CorrectOption": "1930"},
    {"Question": "The only Round Table Conference attended by Mahatma Gandhi was the:", "Option1": "First", "Option2": "Second", "Option3": "Third", "Option4": "Fourth", "CorrectOption": "Second"},
    {"Question": "The Swaraj Party was formed in 1923 by:", "Option1": "Motilal Nehru and Jawaharlal Nehru", "Option2": "C.R. Das and Motilal Nehru", "Option3": "C.R. Das and Subhas Chandra Bose", "Option4": "B.G. Tilak and Annie Besant", "CorrectOption": "C.R. Das and Motilal Nehru"},
    {"Question": "Who established the Depressed Classes Mission Society in Bombay?", "Option1": "Mahatma Gandhi", "Option2": "V.R. Shinde", "Option3": "B.R. Ambedkar", "Option4": "Jyotiba Phule", "CorrectOption": "V.R. Shinde"},
    {"Question": "The Battle of Plassey (1757) was fought between the British forces led by Robert Clive and:", "Option1": "Tipu Sultan", "Option2": "Siraj-ud-Daulah", "Option3": "Mir Jafar", "Option4": "Shuja-ud-Daulah", "CorrectOption": "Siraj-ud-Daulah"},
    {"Question": "The Viceroy of India at the time of the Quit India Movement (1942) was:", "Option1": "Lord Wavell", "Option2": "Lord Linlithgow", "Option3": "Lord Mountbatten", "Option4": "Lord Reading", "CorrectOption": "Lord Linlithgow"},
    {"Question": "Which of the following leaders was associated with the Tebhaga Movement (1946-47)?", "Option1": "Muzaffar Ahmad", "Option2": "A.K. Fazlul Huq", "Option3": "Communist Party Activists", "Option4": "Surendranath Banerjee", "CorrectOption": "Communist Party Activists"},
    {"Question": "The Indian Civil Service (ICS) was established during the tenure of:", "Option1": "Lord Hastings", "Option2": "Lord Cornwallis", "Option3": "Lord Dalhousie", "Option4": "Lord Minto", "CorrectOption": "Lord Cornwallis"}
]

# Create a DataFrame
df_mcqs = pd.DataFrame(mcq_data)

# Save the DataFrame to a CSV file
csv_filename = "UPSC_History_MCQ_Dataset.csv"
df_mcqs.to_csv(csv_filename, index=False)

print(f"Successfully generated '{csv_filename}' with {len(df_mcqs)} questions.")
print("\nHere's a preview of the generated DataFrame:")
print(df_mcqs.head())
# Out:
# Successfully generated 'UPSC_History_MCQ_Dataset.csv' with 100 questions.
#
# Here's a preview of the generated DataFrame:
#                                             Question  \
# 0  With reference to the Indus Valley Civilizatio...
# 1  Which one of the following is known as the 'Bo...
# 2  Which of the following statements about Mahavi...
# 3  Who among the following rulers of the Gupta Dy...
# 4  The famous Chinese pilgrim Fa-Hien visited Ind...
#
#                                              Option1  \
# 0                                       1 and 2 only
# 1                                            Rigveda
# 2  He was the 24th Tirthankara of the Jain tradit...
# 3                                     Chandragupta I
# 4                                             Harsha
#
#                                              Option2  \
# 0                                       2 and 3 only
# 1                                          Yajurveda
# ...
