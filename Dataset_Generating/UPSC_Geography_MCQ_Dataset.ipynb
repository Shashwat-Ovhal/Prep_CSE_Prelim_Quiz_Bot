# %%
import pandas as pd

# Data for the 100 Geography MCQs
mcq_data_geography = [
    # --- Physical Geography & World Geography (Q1-Q20) ---
    {"Question": "Which layer of the Earth's atmosphere is responsible for reflecting radio waves back to Earth?", "Option1": "Troposphere", "Option2": "Stratosphere", "Option3": "Mesosphere", "Option4": "Thermosphere (Ionosphere)", "CorrectOption": "Thermosphere (Ionosphere)"},
    {"Question": "The process by which water vapor changes directly into ice without passing through the liquid phase is called:", "Option1": "Evaporation", "Option2": "Condensation", "Option3": "Sublimation", "Option4": "Deposition (Desublimation)", "CorrectOption": "Deposition (Desublimation)"},
    {"Question": "Which of the following is an erosional landform created by glaciers?", "Option1": "Moraine", "Option2": "Esker", "Option3": "Drumlin", "Option4": "Cirque", "CorrectOption": "Cirque"},
    {"Question": "The term 'Ring of Fire' is associated with which natural hazard?", "Option1": "Hurricanes", "Option2": "Volcanic Eruptions and Earthquakes", "Option3": "Drought", "Option4": "Tsunami", "CorrectOption": "Volcanic Eruptions and Earthquakes"},
    {"Question": "The 'Roaring Forties' are strong westerly winds found primarily between:", "Option1": "$10^\circ$ and $20^\circ$ North latitude", "Option2": "$40^\circ$ and $50^\circ$ South latitude", "Option3": "$60^\circ$ and $70^\circ$ North latitude", "Option4": "Equator and $10^\circ$ North latitude", "CorrectOption": "$40^\circ$ and $50^\circ$ South latitude"},
    {"Question": "Which ocean current is a warm current that significantly influences the climate of Western Europe?", "Option1": "Labrador Current", "Option2": "Benguela Current", "Option3": "Gulf Stream", "Option4": "Canary Current", "CorrectOption": "Gulf Stream"},
    {"Question": "The boundary between the Earth's Crust and Mantle is known as:", "Option1": "Gutenberg Discontinuity", "Option2": "Lehmann Discontinuity", "Option3": "Mohorovičić Discontinuity", "Option4": "Conrad Discontinuity", "CorrectOption": "Mohorovičić Discontinuity"},
    {"Question": "'Plate Tectonics' theory explains the movement of continents. Which scientist is most associated with the continental drift hypothesis?", "Option1": "Charles Darwin", "Option2": "Alfred Wegener", "Option3": "J. Tuzo Wilson", "Option4": "Harry Hess", "CorrectOption": "Alfred Wegener"},
    {"Question": "Which one of the following mountain ranges is an example of a Fold Mountain?", "Option1": "Vosges Mountain", "Option2": "Sierra Nevada", "Option3": "Aravalli Range", "Option4": "Andes Mountains", "CorrectOption": "Andes Mountains"},
    {"Question": "The maximum annual range of temperature is found in:", "Option1": "Equatorial regions", "Option2": "Tropical regions", "Option3": "Polar regions", "Option4": "Temperate regions", "CorrectOption": "Temperate regions"},
    {"Question": "Which gas is the most abundant in the Earth's atmosphere by volume?", "Option1": "Oxygen", "Option2": "Argon", "Option3": "Nitrogen", "Option4": "Carbon Dioxide", "CorrectOption": "Nitrogen"},
    {"Question": "A 'Fjord' is a geographical feature typically found in:", "Option1": "Desert areas", "Option2": "Coastal areas of high latitudes", "Option3": "Tropical rainforests", "Option4": "High plateaus", "CorrectOption": "Coastal areas of high latitudes"},
    {"Question": "The two major components of 'Salinity' in ocean water are:", "Option1": "Calcium Chloride and Sodium Chloride", "Option2": "Sodium Chloride and Magnesium Chloride", "Option3": "Magnesium Sulphate and Potassium Chloride", "Option4": "Calcium Carbonate and Sodium Bicarbonate", "CorrectOption": "Sodium Chloride and Magnesium Chloride"},
    {"Question": "Which type of rainfall is most common in Equatorial regions?", "Option1": "Orographic rainfall", "Option2": "Frontal rainfall", "Option3": "Convectional rainfall", "Option4": "Cyclonic rainfall", "CorrectOption": "Convectional rainfall"},
    {"Question": "The famous 'Great Barrier Reef' is located off the coast of:", "Option1": "South Africa", "Option2": "Australia", "Option3": "Brazil", "Option4": "Mexico", "CorrectOption": "Australia"},
    {"Question": "The term 'Loo' is a local wind primarily found in:", "Option1": "Western Ghats of India", "Option2": "Indo-Gangetic Plain", "Option3": "Coastal regions of Gujarat", "Option4": "North-Eastern states of India", "CorrectOption": "Indo-Gangetic Plain"},
    {"Question": "Which of the following is a sedimentary rock?", "Option1": "Basalt", "Option2": "Marble", "Option3": "Limestone", "Option4": "Granite", "CorrectOption": "Limestone"},
    {"Question": "'Prairies' are temperate grasslands primarily found in:", "Option1": "South America", "Option2": "North America", "Option3": "Australia", "Option4": "Africa", "CorrectOption": "North America"},
    {"Question": "What is the main characteristic of a Tundra Biome?", "Option1": "High rainfall and high temperatures", "Option2": "Hot summers and cold winters", "Option3": "Permafrost and low-growing vegetation", "Option4": "Deep, fertile soil and moderate temperatures", "CorrectOption": "Permafrost and low-growing vegetation"},
    {"Question": "The phenomenon of 'Aphelion' occurs when the Earth is:", "Option1": "Closest to the Sun", "Option2": "Farthest from the Sun", "Option3": "At the Equinox position", "Option4": "At the Solstice position", "CorrectOption": "Farthest from the Sun"},

    # --- Indian Geography (Q21-Q50) ---
    {"Question": "Which latitude passes almost halfway through India?", "Option1": "Tropic of Cancer ($23.5^\circ$ N)", "Option2": "Equator ($0^\circ$)", "Option3": "Tropic of Capricorn ($23.5^\circ$ S)", "Option4": "Arctic Circle ($66.5^\circ$ N)", "CorrectOption": "Tropic of Cancer ($23.5^\circ$ N)"},
    {"Question": "The highest peak in the peninsular plateau region of India is:", "Option1": "Doddabetta", "Option2": "Anai Mudi", "Option3": "Mahendragiri", "Option4": "Kanchenjunga", "CorrectOption": "Anai Mudi"},
    {"Question": "Which river flows through a rift valley in India?", "Option1": "Mahanadi", "Option2": "Godavari", "Option3": "Narmada", "Option4": "Krishna", "CorrectOption": "Narmada"},
    {"Question": "The 'Western Disturbances' that cause rainfall in North-Western India during winter originate in the:", "Option1": "Bay of Bengal", "Option2": "Arabian Sea", "Option3": "Mediterranean Sea", "Option4": "Caspian Sea", "CorrectOption": "Mediterranean Sea"},
    {"Question": "The 'Karewas' formations in Kashmir are famous for the cultivation of:", "Option1": "Apple", "Option2": "Saffron (Zafraan)", "Option3": "Tea", "Option4": "Rice", "CorrectOption": "Saffron (Zafraan)"},
    {"Question": "The longest river of Peninsular India is:", "Option1": "Mahanadi", "Option2": "Godavari", "Option3": "Krishna", "Option4": "Cauvery", "CorrectOption": "Godavari"},
    {"Question": "Which soil type is also known as 'Regur Soil' and is suitable for cotton cultivation?", "Option1": "Alluvial Soil", "Option2": "Red Soil", "Option3": "Black Soil", "Option4": "Laterite Soil", "CorrectOption": "Black Soil"},
    {"Question": "The 'Silent Valley National Park' is located in which state?", "Option1": "Karnataka", "Option2": "Kerala", "Option3": "Tamil Nadu", "Option4": "Andhra Pradesh", "CorrectOption": "Kerala"},
    {"Question": "The 'Barren Island', India's only confirmed active volcano, is located in the:", "Option1": "Lakshadweep Islands", "Option2": "Andaman Islands", "Option3": "Gulf of Kutch", "Option4": "Gulf of Mannar", "CorrectOption": "Andaman Islands"},
    {"Question": "The 'Palghat Gap' (Palakkad Gap) provides a natural passage between:", "Option1": "North India and South India", "Option2": "Western Ghats and Eastern Ghats", "Option3": "Tamil Nadu and Kerala", "Option4": "Deccan Plateau and Konkan Coast", "CorrectOption": "Tamil Nadu and Kerala"},
    {"Question": "The highest population density in India, according to the 2011 Census, is in:", "Option1": "West Bengal", "Option2": "Bihar", "Option3": "Uttar Pradesh", "Option4": "Kerala", "CorrectOption": "Bihar"},
    {"Question": "Which port is known as the 'Queen of the Arabian Sea'?", "Option1": "Mumbai", "Option2": "Kochi", "Option3": "Kandla", "Option4": "Visakhapatnam", "CorrectOption": "Kochi"},
    {"Question": "The 'Doabs' are the fertile plain lands found between:", "Option1": "Two hills", "Option2": "Two rivers", "Option3": "River and Sea", "Option4": "River and Desert", "CorrectOption": "Two rivers"},
    {"Question": "Which one of the following mountain passes is located in the state of Sikkim?", "Option1": "Shipki La", "Option2": "Rohtang Pass", "Option3": "Nathu La", "Option4": "Zoji La", "CorrectOption": "Nathu La"},
    {"Question": "The 'Monsoon Burst' refers to:", "Option1": "The rapid decrease in rainfall during the monsoon season.", "Option2": "The sudden violent onset of rainfall in the early June.", "Option3": "The retreat of the South-West Monsoon.", "Option4": "The period of heavy rainfall in North-Western India.", "CorrectOption": "The sudden violent onset of rainfall in the early June."},
    {"Question": "The 'Keibul Lamjao National Park' is famous for the 'Sangai' (dancing deer) and is located in:", "Option1": "Assam", "Option2": "Manipur", "Option3": "Nagaland", "Option4": "Mizoram", "CorrectOption": "Manipur"},
    {"Question": "The 'Dharwar system' rocks of India are mainly important for:", "Option1": "Coal deposits", "Option2": "Petroleum deposits", "Option3": "Metallic minerals (Iron, Gold)", "Option4": "Non-metallic minerals (Limestone)", "CorrectOption": "Metallic minerals (Iron, Gold)"},
    {"Question": "The largest producer of coffee in India is:", "Option1": "Karnataka", "Option2": "Kerala", "Option3": "Tamil Nadu", "Option4": "Andhra Pradesh", "CorrectOption": "Karnataka"},
    {"Question": "Which one of the following is a major tributary of the River Ganga?", "Option1": "Tapti", "Option2": "Sutlej", "Option3": "Son", "Option4": "Narmada", "CorrectOption": "Son"},
    {"Question": "The 'Great Indian Bustard' is primarily found in the:", "Option1": "Temperate forests of Himalayas", "Option2": "Coastal areas of Odisha", "Option3": "Desert and semi-desert grasslands", "Option4": "Tropical evergreen forests", "CorrectOption": "Desert and semi-desert grasslands"},
    {"Question": "The Indian Standard Time (IST) is based on the longitude of:", "Option1": "$80^\circ$ E", "Option2": "$82^\circ 30'$ E", "Option3": "$82^\circ$ E", "Option4": "$90^\circ$ E", "CorrectOption": "$82^\circ 30'$ E"},
    {"Question": "Which state in India shares a boundary with the maximum number of other states?", "Option1": "Maharashtra", "Option2": "Madhya Pradesh", "Option3": "Uttar Pradesh", "Option4": "Andhra Pradesh", "CorrectOption": "Uttar Pradesh"},
    {"Question": "The 'Meghalaya Plateau' is primarily separated from the Peninsular Plateau by the:", "Option1": "Great Boundary Fault", "Option2": "Malda Gap (Rajmahal-Garo Gap)", "Option3": "Western Ghats", "Option4": "Thar Desert", "CorrectOption": "Malda Gap (Rajmahal-Garo Gap)"},
    {"Question": "Which one of the following is NOT a characteristic feature of the Himalayan rivers?", "Option1": "Deep gorges and V-shaped valleys", "Option2": "Perennial flow of water", "Option3": "Non-navigable in their upper course", "Option4": "Seasonal flow of water", "CorrectOption": "Seasonal flow of water"},
    {"Question": "The highest dam in India, 'Tehri Dam', is constructed on the river:", "Option1": "Ganga", "Option2": "Bhagirathi", "Option3": "Yamuna", "Option4": "Alaknanda", "CorrectOption": "Bhagirathi"},
    {"Question": "The tropical cyclones in the Bay of Bengal mostly develop during the months of:", "Option1": "December-February", "Option2": "March-May", "Option3": "October-November", "Option4": "June-September", "CorrectOption": "October-November"},
    {"Question": "The famous 'Bokaro Steel Plant' was established with the collaboration of which country?", "Option1": "Germany", "Option2": "USA", "Option3": "Russia (then USSR)", "Option4": "UK", "CorrectOption": "Russia (then USSR)"},
    {"Question": "The largest producer of Rubber in India is:", "Option1": "Kerala", "Option2": "Karnataka", "Option3": "Tripura", "Option4": "West Bengal", "CorrectOption": "Kerala"},
    {"Question": "Which one of the following is a key reason for the retreat of the South-West Monsoon?", "Option1": "Low-pressure over North India", "Option2": "High-pressure development over North India", "Option3": "Heating of the Indian Ocean", "Option4": "Shifting of the ITCZ to the north", "CorrectOption": "High-pressure development over North India"},
    {"Question": "The 'Palk Strait' separates India from which country?", "Option1": "Sri Lanka", "Option2": "Maldives", "Option3": "Bangladesh", "Option4": "Pakistan", "CorrectOption": "Sri Lanka"},

    # --- World Geography & Human Geography (Q51-Q100) ---
    {"Question": "The 'Strait of Gibraltar' connects which two water bodies?", "Option1": "Red Sea and Mediterranean Sea", "Option2": "Mediterranean Sea and Atlantic Ocean", "Option3": "North Sea and Atlantic Ocean", "Option4": "Black Sea and Mediterranean Sea", "CorrectOption": "Mediterranean Sea and Atlantic Ocean"},
    {"Question": "Which continent lacks a desert?", "Option1": "South America", "Option2": "North America", "Option3": "Europe", "Option4": "Asia", "CorrectOption": "Europe"},
    {"Question": "The 'Great Artesian Basin' is a significant geographical feature of:", "Option1": "Canada", "Option2": "China", "Option3": "Australia", "Option4": "Argentina", "CorrectOption": "Australia"},
    {"Question": "The concept of 'Demographic Transition' explains the change in:", "Option1": "Population age structure", "Option2": "Population distribution", "Option3": "Birth and death rates", "Option4": "Rural-urban population ratio", "CorrectOption": "Birth and death rates"},
    {"Question": "Which country is the largest producer of natural rubber in the world?", "Option1": "Malaysia", "Option2": "Vietnam", "Option3": "Indonesia", "Option4": "Thailand", "CorrectOption": "Thailand"},
    {"Question": "The 'Kyoto Protocol' is related to:", "Option1": "Protection of wetlands", "Option2": "Reduction of greenhouse gas emissions", "Option3": "Conservation of biodiversity", "Option4": "International trade regulations", "CorrectOption": "Reduction of greenhouse gas emissions"},
    {"Question": "The 'Tropic of Capricorn' passes through which South American country?", "Option1": "Ecuador", "Option2": "Peru", "Option3": "Brazil", "Option4": "Colombia", "CorrectOption": "Brazil"},
    {"Question": "'Slash-and-burn' agriculture is commonly known as 'Jhum' in which part of India?", "Option1": "North India", "Option2": "Western India", "Option3": "North-Eastern India", "Option4": "Southern India", "CorrectOption": "North-Eastern India"},
    {"Question": "Which two countries are separated by the 'Maginot Line'?", "Option1": "Germany and Poland", "Option2": "France and Germany", "Option3": "India and China", "Option4": "North and South Korea", "CorrectOption": "France and Germany"},
    {"Question": "The term 'Megapolis' refers to:", "Option1": "A single-function city", "Option2": "A city with population over 1 million", "Option3": "A clustered group of large cities (conurbation)", "Option4": "A small, historical city", "CorrectOption": "A clustered group of large cities (conurbation)"},
    {"Question": "The 'Suez Canal' connects which two seas?", "Option1": "Red Sea and Mediterranean Sea", "Option2": "Black Sea and Caspian Sea", "Option3": "Arabian Sea and Red Sea", "Option4": "Mediterranean Sea and Black Sea", "CorrectOption": "Red Sea and Mediterranean Sea"},
    {"Question": "The 'Ozone Layer' depletion is primarily caused by:", "Option1": "Carbon Dioxide ($CO_2$)", "Option2": "Methane ($CH_4$)", "Option3": "Chlorofluorocarbons (CFCs)", "Option4": "Sulphur Dioxide ($SO_2$)", "CorrectOption": "Chlorofluorocarbons (CFCs)"},
    {"Question": "Which is the world's highest navigable lake?", "Option1": "Lake Victoria", "Option2": "Lake Baikal", "Option3": "Lake Titicaca", "Option4": "Great Salt Lake", "CorrectOption": "Lake Titicaca"},
    {"Question": "The 'Taiga' biome is dominated by which type of vegetation?", "Option1": "Deciduous trees", "Option2": "Coniferous trees", "Option3": "Grasses", "Option4": "Shrubs and lichens", "CorrectOption": "Coniferous trees"},
    {"Question": "The 'International Date Line' is a conceptual line that primarily follows the:", "Option1": "$0^\circ$ Longitude", "Option2": "$90^\circ$ West Longitude", "Option3": "$180^\circ$ Longitude", "Option4": "Equator", "CorrectOption": "$180^\circ$ Longitude"},
    {"Question": "Which of the following is a major export item from the 'Copper Belt' of Africa?", "Option1": "Iron Ore", "Option2": "Bauxite", "Option3": "Petroleum", "Option4": "Copper", "CorrectOption": "Copper"},
    {"Question": "The 'Doldrums' are a belt of:", "Option1": "High pressure near the tropics", "Option2": "Low pressure near the Equator", "Option3": "Strong winds at high latitudes", "Option4": "Permanent cyclones", "CorrectOption": "Low pressure near the Equator"},
    {"Question": "The 'Tsunami' is generally caused by:", "Option1": "Strong atmospheric winds", "Option2": "Lunar and solar gravitational pull", "Option3": "Submarine earthquakes and volcanic eruptions", "Option4": "Cyclonic storms", "CorrectOption": "Submarine earthquakes and volcanic eruptions"},
    {"Question": "Which country is the leading producer of Wheat in the world?", "Option1": "India", "Option2": "Russia", "Option3": "China", "Option4": "USA", "CorrectOption": "China"},
    {"Question": "The 'Black Earth' (Chernozem) soil is typically found in the:", "Option1": "Equatorial region", "Option2": "Taiga region", "Option3": "Steppes of Ukraine/Russia", "Option4": "Mediterranean region", "CorrectOption": "Steppes of Ukraine/Russia"},
    {"Question": "The largest landlocked country in the world is:", "Option1": "Sudan", "Option2": "Kazakhstan", "Option3": "Mongolia", "Option4": "Chad", "CorrectOption": "Kazakhstan"},
    {"Question": "Which of the following planets is known as the 'Evening Star'?", "Option1": "Mars", "Option2": "Jupiter", "Option3": "Venus", "Option4": "Mercury", "CorrectOption": "Venus"},
    {"Question": "The 'Prime Meridian' passes through:", "Option1": "Paris", "Option2": "New York", "Option3": "Greenwich", "Option4": "New Delhi", "CorrectOption": "Greenwich"},
    {"Question": "The largest river in South America by volume of water is:", "Option1": "Parana River", "Option2": "Amazon River", "Option3": "Orinoco River", "Option4": "Magdalena River", "CorrectOption": "Amazon River"},
    {"Question": "The famous 'Niagara Falls' is located on the border between:", "Option1": "USA and Canada", "Option2": "Brazil and Argentina", "Option3": "China and Russia", "Option4": "India and Nepal", "CorrectOption": "USA and Canada"},
    {"Question": "Which industry is primarily associated with the 'Ruhr region' of Germany?", "Option1": "Textiles", "Option2": "Automobiles", "Option3": "Iron and Steel", "Option4": "Pharmaceuticals", "CorrectOption": "Iron and Steel"},
    {"Question": "'Pastoral Nomadism' is a form of agriculture mainly practiced in:", "Option1": "Monsoon Asia", "Option2": "Tropical Lowlands", "Option3": "Arid and semi-arid regions", "Option4": "Mediterranean region", "CorrectOption": "Arid and semi-arid regions"},
    {"Question": "Which is the deepest oceanic trench in the world?", "Option1": "Tonga Trench", "Option2": "Java Trench", "Option3": "Puerto Rico Trench", "Option4": "Mariana Trench", "CorrectOption": "Mariana Trench"},
    {"Question": "The 'North Sea Gas Field' is a major source of energy for which region?", "Option1": "Eastern Europe", "Option2": "Scandinavia and UK", "Option3": "Middle East", "Option4": "Southeast Asia", "CorrectOption": "Scandinavia and UK"},
    {"Question": "The 'Chinook' is a warm, dry wind that descends the eastern slopes of which mountain range?", "Option1": "Alps", "Option2": "Rockies", "Option3": "Himalayas", "Option4": "Andes", "CorrectOption": "Rockies"},
    {"Question": "Which factor is the most important for the formation of Laterite soils?", "Option1": "Low temperatures and moderate rainfall", "Option2": "High temperatures and high rainfall", "Option3": "Arid climate and high pressure", "Option4": "Presence of volcanic ash", "CorrectOption": "High temperatures and high rainfall"},
    {"Question": "The 'Ecumene' refers to the:", "Option1": "Uninhabited portion of the Earth's surface", "Option2": "Permanently inhabited portion of the Earth's surface", "Option3": "Highly industrialized zone of the world", "Option4": "Coldest parts of the world", "CorrectOption": "Permanently inhabited portion of the Earth's surface"},
    {"Question": "The largest producer of Bauxite (key ore for Aluminium) in the world is:", "Option1": "India", "Option2": "Australia", "Option3": "China", "Option4": "Brazil", "CorrectOption": "Australia"},
    {"Question": "The 'Dead Sea' is known for its high salinity because of:", "Option1": "High evaporation and no outlet", "Option2": "High inflow from large rivers", "Option3": "Volcanic activity at its base", "Option4": "Frequent tsunamis", "CorrectOption": "High evaporation and no outlet"},
    {"Question": "Which of the following is an example of a 'Confluence City' in India?", "Option1": "Mumbai", "Option2": "New Delhi", "Option3": "Prayagraj (Allahabad)", "Option4": "Hyderabad", "CorrectOption": "Prayagraj (Allahabad)"},
    {"Question": "The term 'Urban Heat Island' is associated with:", "Option1": "Low rainfall in urban areas", "Option2": "Higher temperatures in cities compared to surrounding areas", "Option3": "Increased wind speed in urban canyons", "Option4": "Reduced air pollution in city centers", "CorrectOption": "Higher temperatures in cities compared to surrounding areas"},
    {"Question": "The 'Aswan High Dam' is located on which river?", "Option1": "Tigris", "Option2": "Euphrates", "Option3": "Nile", "Option4": "Congo", "CorrectOption": "Nile"},
    {"Question": "The largest archipelago in the world is:", "Option1": "Japan", "Option2": "Philippines", "Option3": "Indonesia", "Option4": "Caribbean", "CorrectOption": "Indonesia"},
    {"Question": "The 'Leeward side' of a mountain range typically receives:", "Option1": "Orographic rainfall", "Option2": "High rainfall", "Option3": "Low rainfall (Rain shadow)", "Option4": "Hailstorms", "CorrectOption": "Low rainfall (Rain shadow)"},
    {"Question": "Which major port of India is located on the East coast?", "Option1": "Mumbai", "Option2": "Kandla", "Option3": "Paradip", "Option4": "Kochi", "CorrectOption": "Paradip"},
    {"Question": "The 'Kuroshio Current' is a warm ocean current found in the:", "Option1": "Atlantic Ocean", "Option2": "Indian Ocean", "Option3": "Pacific Ocean", "Option4": "Arctic Ocean", "CorrectOption": "Pacific Ocean"},
    {"Question": "The 'Mercator Projection' is most commonly used for:", "Option1": "Mapping polar regions", "Option2": "Navigational charts", "Option3": "Land-use planning", "Option4": "Showing population density", "CorrectOption": "Navigational charts"},
    {"Question": "The term 'Greenwich Mean Time (GMT)' is now commonly replaced by:", "Option1": "Universal Time Coordinated (UTC)", "Option2": "International Atomic Time (TAI)", "Option3": "Global Positioning System (GPS) Time", "Option4": "Zonal Time (ZT)", "CorrectOption": "Universal Time Coordinated (UTC)"},
    {"Question": "The 'Pamir Knot' connects which of the following major mountain ranges?", "Option1": "Himalayas and Andes", "Option2": "Himalayas and Karakoram", "Option3": "Andes and Rockies", "Option4": "Alps and Pyrenees", "CorrectOption": "Himalayas and Karakoram"},
    {"Question": "The 'Tidal Forests' in India are also known as:", "Option1": "Tropical Evergreen Forests", "Option2": "Mangrove Forests", "Option3": "Deciduous Forests", "Option4": "Montane Forests", "CorrectOption": "Mangrove Forests"},
    {"Question": "Which one of the following countries does NOT border the Caspian Sea?", "Option1": "Kazakhstan", "Option2": "Iran", "Option3": "Iraq", "Option4": "Turkmenistan", "CorrectOption": "Iraq"},
    {"Question": "The 'Rift Valley' is formed due to:", "Option1": "Folding of the Earth's crust", "Option2": "Faulting of the Earth's crust", "Option3": "Volcanic eruptions", "Option4": "Erosion by rivers", "CorrectOption": "Faulting of the Earth's crust"},
    {"Question": "The 'Klimat' (Climate) classification system was developed by:", "Option1": "Vladimir Köppen", "Option2": "Alfred Wegener", "Option3": "Koppen Geiger", "Option4": "A. L. Kroeber", "CorrectOption": "Vladimir Köppen"},
    {"Question": "The largest number of 'Scheduled Tribes' (ST) in India are concentrated in which state?", "Option1": "Bihar", "Option2": "Madhya Pradesh", "Option3": "Odisha", "Option4": "Jharkhand", "CorrectOption": "Madhya Pradesh"},
    {"Question": "Which of the following crops is primarily associated with 'Horticulture'?", "Option1": "Wheat", "Option2": "Rice", "Option3": "Fruits and Vegetables", "Option4": "Sugarcane", "CorrectOption": "Fruits and Vegetables"}
]

# Create a DataFrame
df_mcqs_geography = pd.DataFrame(mcq_data_geography)

# Save the DataFrame to a CSV file
csv_filename = "UPSC_Geography_MCQ_Dataset.csv"
df_mcqs_geography.to_csv(csv_filename, index=False)

print(f"Successfully generated '{csv_filename}' with {len(df_mcqs_geography)} Geography questions.")
print("\nHere's a preview of the generated DataFrame:")
print(df_mcqs_geography.head())
# Out:
# Successfully generated 'UPSC_Geography_MCQ_Dataset.csv' with 100 Geography questions.
#
# Here's a preview of the generated DataFrame:
#                                             Question  \
# 0  Which layer of the Earth's atmosphere is respo...
# 1  The process by which water vapor changes direc...
# 2  Which of the following is an erosional landfor...
# 3  The term 'Ring of Fire' is associated with whi...
# 4  The 'Roaring Forties' are strong westerly wind...
#
#                                     Option1  \
# 0                               Troposphere
# 1                               Evaporation
# 2                                   Moraine
# 3                                Hurricanes
# 4  $10^\circ$ and $20^\circ$ North latitude
#
#                                     Option2  \
# 0                              Stratosphere
# 1                              Condensation
# 2                                     Esker
# 3        Volcanic Eruptions and Earthquakes
# ...
