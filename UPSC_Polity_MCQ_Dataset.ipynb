# %%
import pandas as pd

# Data for the 100 Indian Polity MCQs
mcq_data_polity = [
    {"Question": "Which feature of the Indian Constitution is borrowed from the British Constitution?", "Option1": "Judicial Review", "Option2": "Rule of Law", "Option3": "Directive Principles of State Policy", "Option4": "Fundamental Rights", "Correct Option": "Rule of Law"},
    {"Question": "The Preamble to the Constitution of India was amended by which Constitutional Amendment Act?", "Option1": "24th Amendment Act", "Option2": "42nd Amendment Act", "Option3": "44th Amendment Act", "Option4": "61st Amendment Act", "Correct Option": "42nd Amendment Act"},
    {"Question": "The 'Basic Structure Doctrine' was propounded by the Supreme Court in which case?", "Option1": "Minerva Mills Case (1980)", "Option2": "Golaknath Case (1967)", "Option3": "Kesavananda Bharati Case (1973)", "Option4": "S.R. Bommai Case (1994)", "Correct Option": "Kesavananda Bharati Case (1973)"},
    {"Question": "Which part of the Constitution deals with the Fundamental Rights?", "Option1": "Part II", "Option2": "Part III", "Option3": "Part IV", "Option4": "Part V", "Correct Option": "Part III"},
    {"Question": "The right to property was removed from the list of Fundamental Rights by the:", "Option1": "24th Amendment", "Option2": "42nd Amendment", "Option3": "44th Amendment", "Option4": "86th Amendment", "Correct Option": "44th Amendment"},
    {"Question": "Which Article of the Constitution abolishes 'untouchability'?", "Option1": "Article 14", "Option2": "Article 17", "Option3": "Article 19", "Option4": "Article 21", "Correct Option": "Article 17"},
    {"Question": "Right to Constitutional Remedies is mentioned under which Article?", "Option1": "Article 20", "Option2": "Article 21", "Option3": "Article 32", "Option4": "Article 51A", "Correct Option": "Article 32"},
    {"Question": "Which one of the following is NOT a writ mentioned in the Constitution of India?", "Option1": "Mandamus", "Option2": "Habeas Corpus", "Option3": "Prohibition", "Option4": "Res Judicata", "Correct Option": "Res Judicata"},
    {"Question": "The Directive Principles of State Policy (DPSP) are contained in which part of the Constitution?", "Option1": "Part III", "Option2": "Part IV", "Option3": "Part IV-A", "Option4": "Part V", "Correct Option": "Part IV"},
    {"Question": "Which committee recommended the inclusion of Fundamental Duties in the Indian Constitution?", "Option1": "Sarkaria Committee", "Option2": "Swaran Singh Committee", "Option3": "Shah Commission", "Option4": "Kothari Commission", "Correct Option": "Swaran Singh Committee"},
    {"Question": "The Fundamental Duties were added to the Constitution by the:", "Option1": "42nd Amendment Act", "Option2": "44th Amendment Act", "Option3": "86th Amendment Act", "Option4": "101st Amendment Act", "Correct Option": "42nd Amendment Act"},
    {"Question": "The President of India is elected by an electoral college consisting of:", "Option1": "Elected members of both Houses of Parliament.", "Option2": "Elected members of both Houses of Parliament and State Legislative Assemblies.", "Option3": "All members of Parliament.", "Option4": "All members of Parliament and State Legislative Assemblies.", "Correct Option": "Elected members of both Houses of Parliament and State Legislative Assemblies."},
    {"Question": "What is the minimum age prescribed for a person to be eligible to be elected as the President of India?", "Option1": "25 years", "Option2": "30 years", "Option3": "35 years", "Option4": "40 years", "Correct Option": "35 years"},
    {"Question": "The President can declare a National Emergency under which Article?", "Option1": "Article 352", "Option2": "Article 356", "Option3": "Article 360", "Option4": "Article 365", "Correct Option": "Article 352"},
    {"Question": "The Vice-President is the ex-officio Chairman of the:", "Option1": "Lok Sabha", "Option2": "Rajya Sabha", "Option3": "Planning Commission (now NITI Aayog)", "Option4": "National Development Council", "Correct Option": "Rajya Sabha"},
    {"Question": "The Council of Ministers is collectively responsible to the:", "Option1": "President", "Option2": "Prime Minister", "Option3": "Rajya Sabha", "Option4": "Lok Sabha", "Correct Option": "Lok Sabha"},
    {"Question": "The maximum strength of the Lok Sabha as envisioned by the Constitution is:", "Option1": "545", "Option2": "550", "Option3": "552", "Option4": "530", "Correct Option": "550"},
    {"Question": "The maximum time gap between two sessions of the Parliament must not exceed:", "Option1": "3 months", "Option2": "6 months", "Option3": "9 months", "Option4": "12 months", "Correct Option": "6 months"},
    {"Question": "A Money Bill can be introduced only in the:", "Option1": "Rajya Sabha", "Option2": "Lok Sabha", "Option3": "Joint Sitting of Parliament", "Option4": "Either House of Parliament", "Correct Option": "Lok Sabha"},
    {"Question": "Who is the final authority to decide whether a bill is a Money Bill or not?", "Option1": "The President", "Option2": "The Vice-President", "Option3": "The Speaker of Lok Sabha", "Option4": "The Finance Minister", "Correct Option": "The Speaker of Lok Sabha"},
    {"Question": "The provision for 'Joint Sitting' of both Houses of Parliament is provided under Article:", "Option1": "Article 100", "Option2": "Article 108", "Option3": "Article 110", "Option4": "Article 118", "Correct Option": "Article 108"},
    {"Question": "The Estimates Committee is exclusively a committee of the:", "Option1": "Lok Sabha", "Option2": "Rajya Sabha", "Option3": "Both Houses jointly", "Option4": "None of the above", "Correct Option": "Lok Sabha"},
    {"Question": "The Supreme Court was established on:", "Option1": "26th January 1950", "Option2": "28th January 1950", "Option3": "15th August 1947", "Option4": "26th November 1949", "Correct Option": "28th January 1950"},
    {"Question": "The 'Judicial Review' power of the Supreme Court is derived from:", "Option1": "Article 13", "Option2": "Article 226", "Option3": "Article 32", "Option4": "Both Article 13 and 32", "Correct Option": "Both Article 13 and 32"},
    {"Question": "The retirement age of a Judge of the Supreme Court is:", "Option1": "60 years", "Option2": "62 years", "Option3": "65 years", "Option4": "70 years", "Correct Option": "65 years"},
    {"Question": "The Governor of a state is appointed by the:", "Option1": "Chief Minister", "Option2": "President", "Option3": "Chief Justice of the High Court", "Option4": "Vice-President", "Correct Option": "President"},
    {"Question": "The Chief Minister of a state is:", "Option1": "Elected by the State Legislative Assembly", "Option2": "Appointed by the Governor", "Option3": "Appointed by the President", "Option4": "Elected by the majority party", "Correct Option": "Appointed by the Governor"},
    {"Question": "The 73rd and 74th Constitutional Amendment Acts are related to:", "Option1": "Fundamental Rights", "Option2": "Centre-State Relations", "Option3": "Panchayats and Municipalities", "Option4": "Judicial Review", "Correct Option": "Panchayats and Municipalities"},
    {"Question": "The Comptroller and Auditor General (CAG) of India is appointed under Article:", "Option1": "Article 76", "Option2": "Article 148", "Option3": "Article 280", "Option4": "Article 324", "Correct Option": "Article 148"},
    {"Question": "The Finance Commission is constituted every five years by the:", "Option1": "Parliament", "Option2": "Prime Minister", "Option3": "President", "Option4": "Finance Minister", "Correct Option": "President"},
    {"Question": "The Election Commission of India is a:", "Option1": "Statutory body", "Option2": "Constitutional body", "Option3": "Executive body", "Option4": "None of the above", "Correct Option": "Constitutional body"},
    {"Question": "The Union Public Service Commission (UPSC) members are appointed by the:", "Option1": "Parliament", "Option2": "President", "Option3": "Prime Minister", "Option4": "Speaker", "Correct Option": "President"},
    {"Question": "Which Article deals with the Right to Education (RTE) as a Fundamental Right?", "Option1": "Article 21", "Option2": "Article 21A", "Option3": "Article 45", "Option4": "Article 51A(k)", "Correct Option": "Article 21A"},
    {"Question": "The Inter-State Council is established under Article:", "Option1": "Article 262", "Option2": "Article 263", "Option3": "Article 280", "Option4": "Article 275", "Correct Option": "Article 263"},
    {"Question": "Which of the following is NOT a feature of a Federal System?", "Option1": "Dual Government", "Option2": "Division of Powers", "Option3": "Single Citizenship", "Option4": "Written Constitution", "Correct Option": "Single Citizenship"},
    {"Question": "The concept of 'Procedure Established by Law' is borrowed from which country's constitution?", "Option1": "USA", "Option2": "UK", "Option3": "Japan", "Option4": "Canada", "Correct Option": "Japan"},
    {"Question": "Which Schedule of the Constitution deals with the division of powers between the Union and the States?", "Option1": "Sixth Schedule", "Option2": "Seventh Schedule", "Option3": "Eighth Schedule", "Option4": "Ninth Schedule", "Correct Option": "Seventh Schedule"},
    {"Question": "The Official Languages of India are listed in which Schedule?", "Option1": "Seventh Schedule", "Option2": "Eighth Schedule", "Option3": "Ninth Schedule", "Option4": "Tenth Schedule", "Correct Option": "Eighth Schedule"},
    {"Question": "The power to make laws on a subject not enumerated in any of the three lists (Residuary Power) rests with:", "Option1": "State Legislature", "Option2": "Parliament", "Option3": "President", "Option4": "Both Parliament and State Legislature", "Correct Option": "Parliament"},
    {"Question": "The National Human Rights Commission (NHRC) is a:", "Option1": "Constitutional body", "Option2": "Statutory body", "Option3": "Executive body", "Option4": "Quasi-judicial body", "Correct Option": "Statutory body"},
    {"Question": "The President can seek the advisory opinion of the Supreme Court under Article:", "Option1": "Article 141", "Option2": "Article 142", "Option3": "Article 143", "Option4": "Article 148", "Correct Option": "Article 143"},
    {"Question": "The minimum age for a member of the Rajya Sabha is:", "Option1": "25 years", "Option2": "30 years", "Option3": "35 years", "Option4": "No minimum age", "Correct Option": "30 years"},
    {"Question": "Who presides over the Joint Sitting of the two Houses of Parliament?", "Option1": "The President", "Option2": "The Vice-President", "Option3": "The Speaker of Lok Sabha", "Option4": "The Prime Minister", "Correct Option": "The Speaker of Lok Sabha"},
    {"Question": "The Anti-defection Law is provided in which Schedule of the Constitution?", "Option1": "Ninth Schedule", "Option2": "Tenth Schedule", "Option3": "Eleventh Schedule", "Option4": "Twelfth Schedule", "Correct Option": "Tenth Schedule"},
    {"Question": "The constitutional provision for the National Commission for Scheduled Castes (NCSC) is under Article:", "Option1": "Article 330", "Option2": "Article 338", "Option3": "Article 340", "Option4": "Article 342", "Correct Option": "Article 338"},
    {"Question": "Which is the only Union Territory that has a High Court of its own?", "Option1": "Puducherry", "Option2": "Chandigarh", "Option3": "Delhi", "Option4": "Andaman and Nicobar Islands", "Correct Option": "Delhi"},
    {"Question": "The maximum term of an Ordinance promulgated by the President is:", "Option1": "6 weeks", "Option2": "6 months", "Option3": "6 months and 6 weeks", "Option4": "1 year", "Correct Option": "6 months and 6 weeks"},
    {"Question": "The concept of 'Equal Pay for Equal Work' is a:", "Option1": "Fundamental Right", "Option2": "Directive Principle of State Policy", "Option3": "Fundamental Duty", "Option4": "Statutory Right", "Correct Option": "Directive Principle of State Policy"},
    {"Question": "Proclamation of Financial Emergency requires a Parliamentary approval within:", "Option1": "1 month", "Option2": "2 months", "Option3": "6 months", "Option4": "1 year", "Correct Option": "2 months"},
    {"Question": "The Central Vigilance Commission (CVC) was established on the recommendation of which committee?", "Option1": "Santhanam Committee", "Option2": "Sarkaria Commission", "Option3": "L.M. Singhvi Committee", "Option4": "Ashok Mehta Committee", "Correct Option": "Santhanam Committee"},
    {"Question": "The phrase 'Secular' was added to the Preamble by the:", "Option1": "42nd Amendment", "Option2": "44th Amendment", "Option3": "86th Amendment", "Option4": "It was always there", "Correct Option": "42nd Amendment"},
    {"Question": "Article 20 of the Constitution provides protection in respect of:", "Option1": "Right to Life", "Option2": "Protection against arrest", "Option3": "Protection against double jeopardy and self-incrimination", "Option4": "Right to equality", "Correct Option": "Protection against double jeopardy and self-incrimination"},
    {"Question": "The constitutional provision for Gram Sabha is covered under which amendment?", "Option1": "72nd Amendment", "Option2": "73rd Amendment", "Option3": "74th Amendment", "Option4": "97th Amendment", "Correct Option": "73rd Amendment"},
    {"Question": "The minimum number of members required to move a No-Confidence Motion in the Lok Sabha is:", "Option1": "50 members", "Option2": "100 members", "Option3": "50% of total strength", "Option4": "1/3rd of total strength", "Correct Option": "50 members"},
    {"Question": "Which Article provides for the freedom of conscience and free profession, practice and propagation of religion?", "Option1": "Article 25", "Option2": "Article 26", "Option3": "Article 27", "Option4": "Article 28", "Correct Option": "Article 25"},
    {"Question": "The Attorney General of India holds office during the pleasure of the:", "Option1": "Parliament", "Option2": "Prime Minister", "Option3": "President", "Option4": "Chief Justice of India", "Correct Option": "President"},
    {"Question": "Which constitutional amendment gave a constitutional status to the National Commission for Backward Classes (NCBC)?", "Option1": "101st Amendment", "Option2": "102nd Amendment", "Option3": "103rd Amendment", "Option4": "104th Amendment", "Correct Option": "102nd Amendment"},
    {"Question": "The Rajya Sabha has special powers to create a new All India Service under Article:", "Option1": "Article 249", "Option2": "Article 312", "Option3": "Article 352", "Option4": "Article 368", "Correct Option": "Article 312"},
    {"Question": "The first ever constitutional amendment was done in:", "Option1": "1950", "Option2": "1951", "Option3": "1952", "Option4": "1956", "Correct Option": "1951"},
    {"Question": "The power to legislate on subjects in the Concurrent List rests with:", "Option1": "Union only", "Option2": "States only", "Option3": "Both Union and States", "Option4": "Neither Union nor States", "Correct Option": "Both Union and States"},
    {"Question": "A constitutional government is, by definition, a:", "Option1": "Government by legislature", "Option2": "Limited government", "Option3": "Multi-party government", "Option4": "Popular government", "Correct Option": "Limited government"},
    {"Question": "The Ninth Schedule was added by which Amendment Act?", "Option1": "First Amendment", "Option2": "Seventh Amendment", "Option3": "24th Amendment", "Option4": "42nd Amendment", "Correct Option": "First Amendment"},
    {"Question": "The 'Electoral College' for the election of the President of India includes:", "Option1": "Elected members of Legislative Councils", "Option2": "Nominated members of Rajya Sabha", "Option3": "Elected members of State Legislative Assemblies", "Option4": "Members of Municipal Corporations", "Correct Option": "Elected members of State Legislative Assemblies"},
    {"Question": "The system of Proportional Representation is used for the election of:", "Option1": "Lok Sabha", "Option2": "President", "Option3": "Governor", "Option4": "Chief Minister", "Correct Option": "President"},
    {"Question": "The Panchayats are required to hold elections every:", "Option1": "3 years", "Option2": "4 years", "Option3": "5 years", "Option4": "6 years", "Correct Option": "5 years"},
    {"Question": "The provision for 'Writs' jurisdiction of the High Court is provided under Article:", "Option1": "Article 32", "Option2": "Article 226", "Option3": "Article 139", "Option4": "Article 245", "Correct Option": "Article 226"},
    {"Question": "The power to amend the Constitution is vested in the:", "Option1": "Supreme Court", "Option2": "President", "Option3": "Parliament", "Option4": "State Legislatures", "Correct Option": "Parliament"},
    {"Question": "The Age of Voting was reduced from 21 to 18 years by which Amendment Act?", "Option1": "44th Amendment", "Option2": "61st Amendment", "Option3": "73rd Amendment", "Option4": "86th Amendment", "Correct Option": "61st Amendment"},
    {"Question": "The Council of Ministers at the Union level cannot exceed what percentage of the total strength of the Lok Sabha?", "Option1": "10%", "Option2": "15%", "Option3": "20%", "Option4": "25%", "Correct Option": "15%"},
    {"Question": "The National Commission for SCs, STs, and OBCs submit their annual reports to the:", "Option1": "Prime Minister", "Option2": "Parliament", "Option3": "President", "Option4": "Speaker of Lok Sabha", "Correct Option": "President"},
    {"Question": "Which Directive Principle was added by the 42nd Amendment and requires the state to secure opportunities for the healthy development of children?", "Option1": "Article 39(f)", "Option2": "Article 40", "Option3": "Article 44", "Option4": "Article 48A", "Correct Option": "Article 39(f)"},
    {"Question": "The President's Rule in a state can be extended for a maximum period of:", "Option1": "1 year", "Option2": "2 years", "Option3": "3 years", "Option4": "6 months", "Correct Option": "3 years"},
    {"Question": "The Chairman of the Public Accounts Committee is traditionally appointed from the:", "Option1": "Ruling Party", "Option2": "Opposition Party", "Option3": "Lok Sabha", "Option4": "Rajya Sabha", "Correct Option": "Opposition Party"},
    {"Question": "'Habeas Corpus' literally means:", "Option1": "We command", "Option2": "To be certified", "Option3": "By what authority", "Option4": "To have the body of", "Correct Option": "To have the body of"},
    {"Question": "The power of the Supreme Court to punish for Contempt of itself is a:", "Option1": "Statutory power", "Option2": "Constitutional power", "Option3": "Convention", "Option4": "Power derived from Parliament", "Correct Option": "Constitutional power"},
    {"Question": "The Planning Commission (now NITI Aayog) is a:", "Option1": "Constitutional body", "Option2": "Statutory body", "Option3": "Non-constitutional and non-statutory body", "Option4": "Quasi-judicial body", "Correct Option": "Non-constitutional and non-statutory body"},
    {"Question": "Which Article deals with the Uniform Civil Code (UCC)?", "Option1": "Article 40", "Option2": "Article 44", "Option3": "Article 48", "Option4": "Article 50", "Correct Option": "Article 44"},
    {"Question": "The Fundamental Rights can be suspended during a National Emergency, except for which two Articles?", "Option1": "Article 19 and 20", "Option2": "Article 20 and 21", "Option3": "Article 21 and 22", "Option4": "Article 14 and 19", "Correct Option": "Article 20 and 21"},
    {"Question": "The total number of members in the National Development Council (NDC) are:", "Option1": "Fixed by the Constitution", "Option2": "Fixed by the Parliament", "Option3": "Varying, including CMs of all states", "Option4": "Fixed at 50", "Correct Option": "Varying, including CMs of all states"},
    {"Question": "The Speaker of the Lok Sabha addresses his resignation to the:", "Option1": "President", "Option2": "Prime Minister", "Option3": "Deputy Speaker of Lok Sabha", "Option4": "Chief Justice of India", "Correct Option": "Deputy Speaker of Lok Sabha"},
    {"Question": "The concept of 'Lokayukta' was first introduced in which state?", "Option1": "Bihar", "Option2": "Maharashtra", "Option3": "Orissa", "Option4": "Karnataka", "Correct Option": "Maharashtra"},
    {"Question": "Which Article of the Constitution gives special status to the state of Jammu and Kashmir (now repealed)?", "Option1": "Article 370", "Option2": "Article 371", "Option3": "Article 372", "Option4": "Article 377", "Correct Option": "Article 370"},
    {"Question": "The provision for a Bicameral Legislature at the state level is:", "Option1": "Compulsory for all states", "Option2": "Optional for states", "Option3": "Present in all states", "Option4": "Abolished by 42nd Amendment", "Correct Option": "Optional for states"},
    {"Question": "The oath of office to the Governor is administered by the:", "Option1": "President", "Option2": "Chief Minister", "Option3": "Chief Justice of the concerned High Court", "Option4": "Speaker of the Legislative Assembly", "Correct Option": "Chief Justice of the concerned High Court"},
    {"Question": "The Minimum Wages Act was enacted in which year?", "Option1": "1947", "Option2": "1948", "Option3": "1950", "Option4": "1952", "Correct Option": "1948"},
    {"Question": "The Welfare State concept in the Indian Constitution is included in the:", "Option1": "Preamble", "Option2": "Fundamental Rights", "Option3": "Directive Principles of State Policy", "Option4": "Seventh Schedule", "Correct Option": "Directive Principles of State Policy"},
    {"Question": "Which statement is correct regarding the Emergency Provisions?", "Option1": "All three types of emergencies are mentioned in the Constitution.", "Option2": "The proclamation of National Emergency needs approval from the Parliament within one month.", "Option3": "Financial Emergency has been imposed twice in India.", "Option4": "National Emergency automatically suspends all Fundamental Rights.", "Correct Option": "The proclamation of National Emergency needs approval from the Parliament within one month."},
    {"Question": "The maximum strength of the Rajya Sabha is:", "Option1": "250", "Option2": "252", "Option3": "545", "Option4": "550", "Correct Option": "250"},
    {"Question": "The President of India is part of the:", "Option1": "Executive", "Option2": "Legislature", "Option3": "Judiciary", "Option4": "Both Executive and Legislature", "Correct Option": "Both Executive and Legislature"},
    {"Question": "The 'Question Hour' in Parliament is conducted:", "Option1": "First hour of every sitting", "Option2": "Last hour of every sitting", "Option3": "Before the lunch break", "Option4": "After the lunch break", "Correct Option": "First hour of every sitting"},
    {"Question": "The Right to Privacy is protected as an intrinsic part of the Right to Life and Personal Liberty under which Article?", "Option1": "Article 14", "Option2": "Article 19", "Option3": "Article 21", "Option4": "Article 32", "Correct Option": "Article 21"},
    {"Question": "The 'Whip' in a political party is responsible for:", "Option1": "Collecting funds for the party", "Option2": "Ensuring party members vote according to the party line", "Option3": "Chairing all party meetings", "Option4": "Representing the party in court", "Correct Option": "Ensuring party members vote according to the party line"},
    {"Question": "Money Bills passed by the Lok Sabha are sent to the Rajya Sabha, which can delay them for a maximum of:", "Option1": "7 days", "Option2": "14 days", "Option3": "30 days", "Option4": "6 months", "Correct Option": "14 days"},
    {"Question": "Which Article empowers the Parliament to form a new state by separation of territory from any state?", "Option1": "Article 1", "Option2": "Article 2", "Option3": "Article 3", "Option4": "Article 4", "Correct Option": "Article 3"},
    {"Question": "The Fundamental Duties obligate citizens to safeguard:", "Option1": "Public property", "Option2": "Private property", "Option3": "Both Public and Private property", "Option4": "The dignity of individuals", "Correct Option": "Public property"},
    {"Question": "The Public Accounts Committee examines the report of the:", "Option1": "Finance Commission", "Option2": "Comptroller and Auditor General (CAG)", "Option3": "Attorney General", "Option4": "National Human Rights Commission", "Correct Option": "Comptroller and Auditor General (CAG)"},
    {"Question": "The Constitutional Amendment Bill must be passed in each House by:", "Option1": "Simple majority", "Option2": "Special majority", "Option3": "Simple majority in Lok Sabha and Special majority in Rajya Sabha", "Option4": "Special majority in each House", "Correct Option": "Special majority in each House"},
    {"Question": "The National Commission for Women is a:", "Option1": "Constitutional body", "Option2": "Statutory body", "Option3": "Quasi-judicial body", "Option4": "Executive body", "Correct Option": "Statutory body"},
    {"Question": "The maximum number of nominated members in the Rajya Sabha is:", "Option1": "2", "Option2": "10", "Option3": "12", "Option4": "14", "Correct Option": "12"},
    {"Question": "The Independence of the Judiciary in the Indian Constitution is borrowed from:", "Option1": "UK Constitution", "Option2": "US Constitution", "Option3": "Canadian Constitution", "Option4": "Irish Constitution", "Correct Option": "US Constitution"},
    {"Question": "Which Constitutional Amendment Act made it obligatory for the President to give his assent to a Constitutional Amendment Bill?", "Option1": "24th Amendment", "Option2": "42nd Amendment", "Option3": "44th Amendment", "Option4": "86th Amendment", "Correct Option": "24th Amendment"},
    {"Question": "The concept of 'Residuary Powers' has been borrowed from the Constitution of:", "Option1": "USA", "Option2": "Australia", "Option3": "Canada", "Option4": "Ireland", "Correct Option": "Canada"},
    {"Question": "Who among the following is not a member of the electoral college for the election of the Vice-President?", "Option1": "Elected members of Lok Sabha", "Option2": "Elected members of Rajya Sabha", "Option3": "Nominated members of Parliament", "Option4": "Members of State Legislative Assemblies", "Correct Option": "Members of State Legislative Assemblies"},
    {"Question": "The power of 'Judicial Activism' has been largely exercised through which of the following?", "Option1": "Advisory Jurisdiction", "Option2": "Public Interest Litigation (PIL)", "Option3": "Original Jurisdiction", "Option4": "Writ Jurisdiction", "Correct Option": "Public Interest Litigation (PIL)"},
    {"Question": "Which Article allows the formation of Cooperative Societies?", "Option1": "Article 19(1)(c)", "Option2": "Article 21A", "Option3": "Article 40", "Option4": "Article 51", "Correct Option": "Article 19(1)(c)"},
    {"Question": "The provision for the **'Zero Hour'** in the Indian Parliament is:", "Option1": "Mentioned in the Constitution", "Option2": "Mentioned in the Rules of Procedure", "Option3": "An innovation of the Indian Parliament", "Option4": "Borrowed from the UK Parliament", "Correct Option": "An innovation of the Indian Parliament"},
    {"Question": "The maximum number of seats reserved for Scheduled Castes in the Lok Sabha is as per:", "Option1": "Delimitation Commission", "Option2": "Constitution of India", "Option3": "Election Commission", "Option4": "President's Order", "Correct Option": "Delimitation Commission"},
    {"Question": "Which part of the Constitution contains the temporary, transitional, and special provisions?", "Option1": "Part XVII", "Option2": "Part XVIII", "Option3": "Part XIX", "Option4": "Part XXI", "Correct Option": "Part XXI"},
    {"Question": "Which constitutional amendment made the right to form cooperative societies a fundamental right?", "Option1": "91st Amendment", "Option2": "97th Amendment", "Option3": "99th Amendment", "Option4": "100th Amendment", "Correct Option": "97th Amendment"},
    {"Question": "The **First Law Commission** was established in India under the chairmanship of:", "Option1": "B.R. Ambedkar", "Option2": "M.C. Setalvad", "Option3": "K.V.K. Sundaram", "Option4": "V.P. Menon", "Correct Option": "M.C. Setalvad"},
    {"Question": "The **Official Language** of the Union is Hindi in Devanagari script, as per Article:", "Option1": "Article 343", "Option2": "Article 345", "Option3": "Article 347", "Option4": "Article 348", "Correct Option": "Article 343"},
    {"Question": "Which body/authority is empowered to regulate the procedure and conduct of business in the Rajya Sabha?", "Option1": "President", "Option2": "Rajya Sabha Secretariat", "Option3": "Vice-President (Chairman)", "Option4": "Minister of Parliamentary Affairs", "Correct Option": "Vice-President (Chairman)"},
    {"Question": "A constitutional amendment involving the federal structure (like Article 368) requires ratification by:", "Option1": "Majority of State Legislatures", "Option2": "At least one-half of the State Legislatures", "Option3": "Two-thirds of the State Legislatures", "Option4": "All State Legislatures", "Correct Option": "At least one-half of the State Legislatures"},
    {"Question": "Which feature of the Constitution ensures the independence of the CAG?", "Option1": "Fixed tenure and removal process similar to a SC Judge", "Option2": "Appointed by the President", "Option3": "Report submitted directly to Parliament", "Option4": "He is not eligible for further office", "Correct Option": "Fixed tenure and removal process similar to a SC Judge"},
    {"Question": "The provision for **'Office of Profit'** is dealt with in the Constitution to maintain:", "Option1": "Federalism", "Option2": "Separation of powers", "Option3": "Independence of the legislature", "Option4": "Judicial independence", "Correct Option": "Independence of the legislature"},
    {"Question": "Which committee recommended the three-tier structure for Panchayati Raj?", "Option1": "Ashok Mehta Committee", "Option2": "L.M. Singhvi Committee", "Option3": "Balwant Rai Mehta Committee", "Option4": "G.V.K. Rao Committee", "Correct Option": "Balwant Rai Mehta Committee"},
    {"Question": "The **Right to form Associations or Unions** is guaranteed under which Article?", "Option1": "Article 14", "Option2": "Article 19(1)(c)", "Option3": "Article 20", "Option4": "Article 22", "Correct Option": "Article 19(1)(c)"},
    {"Question": "A member of the State Public Service Commission can be removed by the:", "Option1": "Governor on recommendation of CM", "Option2": "President on report of Supreme Court", "Option3": "Governor alone", "Option4": "State Legislature", "Correct Option": "President on report of Supreme Court"},
    {"Question": "The **Protem Speaker** of the Lok Sabha is:", "Option1": "Appointed by the Vice-President", "Option2": "Elected by the members of Lok Sabha", "Option3": "Usually the senior-most member of the House", "Option4": "The longest serving Speaker of the previous Lok Sabha", "Correct Option": "Usually the senior-most member of the House"},
    {"Question": "The total number of judges in the Supreme Court, including the Chief Justice, is determined by the:", "Option1": "President", "Option2": "Parliament", "Option3": "Supreme Court collegium", "Option4": "Ministry of Law and Justice", "Correct Option": "Parliament"},
    {"Question": "Which Article provides for the **establishment of administrative tribunals**?", "Option1": "Article 323A", "Option2": "Article 324", "Option3": "Article 330", "Option4": "Article 335", "Correct Option": "Article 323A"},
    {"Question": "The **Fundamental Duties** are:", "Option1": "Justiciable", "Option2": "Non-justiciable", "Option3": "Partially justiciable", "Option4": "Enforceable by an Act of Parliament only", "Correct Option": "Non-justiciable"},
    {"Question": "The **'Doctrine of Colourable Legislation'** is related to the principle of:", "Option1": "Judicial Review", "Option2": "Separation of Powers", "Option3": "Delegated Legislation", "Option4": "Parliamentary Sovereignty", "Correct Option": "Delegated Legislation"},
    {"Question": "Which constitutional provision defines the term 'State' for the purposes of Fundamental Rights?", "Option1": "Article 11", "Option2": "Article 12", "Option3": "Article 13", "Option4": "Article 14", "Correct Option": "Article 12"},
    {"Question": "The High Courts have the power of superintendence over all courts and tribunals throughout the territory under their jurisdiction (excluding military courts) under Article:", "Option1": "Article 214", "Option2": "Article 226", "Option3": "Article 227", "Option4": "Article 229", "Correct Option": "Article 227"},
    {"Question": "Which is the first city in India to have a Municipal Corporation?", "Option1": "Bombay", "Option2": "Calcutta", "Option3": "Madras", "Option4": "Delhi", "Correct Option": "Madras"},
    {"Question": "The **'System of Special Majority'** for constitutional amendment is a blend of:", "Option1": "Flexibility and Rigidity", "Option2": "Federalism and Unitarianism", "Option3": "Judicial Review and Parliamentary Supremacy", "Option4": "Rule of Law and Due Process of Law", "Correct Option": "Flexibility and Rigidity"},
    {"Question": "The **'Doctrine of Pith and Substance'** is used to solve disputes related to:", "Option1": "Fundamental Rights vs. DPSP", "Option2": "President vs. Prime Minister powers", "Option3": "Legislative competence of Union and State", "Option4": "Executive vs. Judicial powers", "Correct Option": "Legislative competence of Union and State"},
    {"Question": "The **Finance Commission** recommends the distribution of the net proceeds of taxes between the Union and the States under Article:", "Option1": "Article 275", "Option2": "Article 280", "Option3": "Article 292", "Option4": "Article 301", "Correct Option": "Article 280"},
    {"Question": "Which body conducts the elections to the Panchayats and Municipalities?", "Option1": "Election Commission of India", "Option2": "State Election Commission", "Option3": "Panchayat Development Department", "Option4": "Governor's Office", "Correct Option": "State Election Commission"},
    {"Question": "The concept of **'Due Process of Law'** is a feature of the constitution of:", "Option1": "India", "Option2": "USA", "Option3": "UK", "Option4": "Japan", "Correct Option": "USA"},
    {"Question": "The President can issue an order for the enforcement of Fundamental Rights during an Emergency only with respect to:", "Option1": "Article 19", "Option2": "Articles 20 and 21", "Option3": "Any Fundamental Right except Article 20 and 21", "Option4": "All Fundamental Rights", "Correct Option": "Any Fundamental Right except Article 20 and 21"},
    {"Question": "Which Constitutional Amendment Act added the word **'Integrity'** to the Preamble?", "Option1": "24th Amendment", "Option2": "42nd Amendment", "Option3": "44th Amendment", "Option4": "86th Amendment", "Correct Option": "42nd Amendment"},
    {"Question": "The **'Doctrine of Severability'** is related to which Article?", "Option1": "Article 13", "Option2": "Article 14", "Option3": "Article 19", "Option4": "Article 368", "Correct Option": "Article 13"},
    {"Question": "The **Central Bureau of Investigation (CBI)** is established as a:", "Option1": "Constitutional body", "Option2": "Statutory body by an Act of Parliament", "Option3": "Body by an executive resolution", "Option4": "Autonomous body under the Supreme Court", "Correct Option": "Body by an executive resolution"},
    {"Question": "The **Oath of the President of India** is administered by the:", "Option1": "Vice-President", "Option2": "Prime Minister", "Option3": "Chief Justice of India", "Option4": "Speaker of Lok Sabha", "Correct Option": "Chief Justice of India"},
    {"Question": "Which Article provides for the **'Protection of monuments and places and objects of national importance'**?", "Option1": "Article 49", "Option2": "Article 50", "Option3": "Article 51", "Option4": "Article 51A", "Correct Option": "Article 49"},
    {"Question": "The maximum number of members in a **State Legislative Assembly** can be:", "Option1": "400", "Option2": "500", "Option3": "550", "Option4": "600", "Correct Option": "500"},
    {"Question": "The **'Welfare State'** in India is based on the principle of:", "Option1": "Utilitarianism", "Option2": "Socialism", "Option3": "Communism", "Option4": "Liberalism", "Correct Option": "Socialism"},
    {"Question": "The **'Anti-Defection Law'** gives the final power to decide on disqualification to the:", "Option1": "Election Commission", "Option2": "Supreme Court", "Option3": "Presiding Officer of the House", "Option4": "President", "Correct Option": "Presiding Officer of the House"},
    {"Question": "The **Ninth Schedule** primarily deals with the: ", "Option1": "Land reforms and abolition of the Zamindari system", "Option2": "Panchayats and Municipalities", "Option3": "Languages of India", "Option4": "Anti-Defection Law", "Correct Option": "Land reforms and abolition of the Zamindari system"}
]

# Create a DataFrame
df_mcqs_polity = pd.DataFrame(mcq_data_polity)

# Save the DataFrame to a CSV file
csv_filename = "UPSC_Polity_MCQ_Dataset.csv"
df_mcqs_polity.to_csv(csv_filename, index=False)

# Display confirmation and preview
print(f"✅ Successfully generated '{csv_filename}' with {len(df_mcqs_polity)} Indian Polity questions.")
print("\n---")
print("Here's a preview of the generated DataFrame:")
print(df_mcqs_polity.head())
# Out:
# ✅ Successfully generated 'UPSC_Polity_MCQ_Dataset.csv' with 141 Indian Polity questions.
#
# ---
# Here's a preview of the generated DataFrame:
#                                             Question  \
# 0  Which feature of the Indian Constitution is bo...
# 1  The Preamble to the Constitution of India was ...
# 2  The 'Basic Structure Doctrine' was propounded ...
# 3  Which part of the Constitution deals with the ...
# 4  The right to property was removed from the lis...
#
#                      Option1                Option2  \
# 0            Judicial Review            Rule of Law
# 1         24th Amendment Act     42nd Amendment Act
# 2  Minerva Mills Case (1980)  Golaknath Case (1967)
# 3                    Part II               Part III
# 4             24th Amendment         42nd Amendment
#
#                                 Option3                  Option4  \
# 0  Directive Principles of State Policy       Fundamental Rights
# ...
