# %%
import pandas as pd

# %%
df_history = pd.read_csv("UPSC_History_MCQ_Dataset.csv")
print(df_history.head())
# Out:
#                                             Question              Option1  \
# 0          Who was the founder of the Maurya Empire?  Chandragupta Maurya
# 1        Which of the following was a Harappan port?               Lothal
# 2             The Rigveda is mainly a collection of:              Prayers
# 3  Who among the following was associated with th...  Bal Gangadhar Tilak
# 4     The famous book 'Arthashastra' was written by:             Kautilya
#
#            Option2                 Option3               Option4  \
# 0        Bindusara                  Ashoka             Bimbisara
# 1       Kalibangan            Mohenjo-Daro            Rakhigarhi
# 2          Rituals  Philosophical thoughts  Mythological stories
# 3  Lala Lajpat Rai    Subhash Chandra Bose        Mahatma Gandhi
# 4         Kalidasa              Vatsyayana              Chanakya
#
#          CorrectOption
# 0  Chandragupta Maurya
# 1               Lothal
# 2              Prayers
# 3  Bal Gangadhar Tilak
# 4             Kautilya

# %%
name = input("Enter your name: ")
print(f"Hello, {name}! Welcome to your personalized MCQ practicer")
# Out:
# Hello, Shashwat! Welcome to your personalized MCQ practicer

# %%
options = {1:"History", 2:"Georaphy", 3:"Science", 4:"Sports", 5:"Entertainment"}
choice = int(input(("Select Subject to practice by entering the sequence no. for following options:\n1. History\n2. Geography\n3. Science\n4. Sports\n5. Entertainment")))
print(f"Let's start practicing {options[choice]} questions, {name}!")
print("Press 'Exits' to stop the test and see your score at any time.")
# Out:
# Let's start practicing History questions, Shashwat!
# Press 'Exits' to stop the test and see your score at any time.
